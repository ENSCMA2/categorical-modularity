# %%
# fasttext, 1 trial
from scipy import stats
import csv
scores2 = {"b normalized": {}, "c normalized": {}, "d normalized": {},
          "b unnormalized": {}, "c unnormalized": {}, "d unnormalized": {}}
scores3 = {"b normalized": {}, "c normalized": {}, "d normalized": {},
          "b unnormalized": {}, "c unnormalized": {}, "d unnormalized": {}}
scores4 = {"b normalized": {}, "c normalized": {}, "d normalized": {},
          "b unnormalized": {}, "c unnormalized": {}, "d unnormalized": {}}
conversion = {"du": "d unnormalized", "dn": "d normalized",
              "cu": "c unnormalized", "cn": "c normalized",
              "bu": "b unnormalized", "bn": "b normalized"}
for k in conversion.keys():
  with open(k + "2.csv", newline="") as csvfile:
    reader = csv.reader(csvfile)
    rows = [row for row in reader]
    for i in range(len(rows[0][1:])):
      scores2[conversion[k]][rows[0][i + 1]] = [float(score[i + 1]) for score in rows[1:]]
for k in conversion.keys():
  with open(k + "3.csv", newline="") as csvfile:
    reader = csv.reader(csvfile)
    rows = [row for row in reader]
    for i in range(len(rows[0][1:])):
      scores3[conversion[k]][rows[0][i + 1]] = [float(score[i + 1]) for score in rows[1:]]
for k in conversion.keys():
  with open(k + "4.csv", newline="") as csvfile:
    reader = csv.reader(csvfile)
    rows = [row for row in reader]
    for i in range(len(rows[0][1:])):
      scores4[conversion[k]][rows[0][i + 1]] = [float(score[i + 1]) for score in rows[1:]]
performance = {"b": {"svm accuracy": [0.74, 0.68, 0.78, 0.67, 0.73, 0.71, 0.83, 0.82, 0.85, 0.74, 0.81, 0.81,
0.52, 0.83, 0.82, 0.78, 0.72, 0.69, 0.81, 0.73, 0.74, 0.85, 0.7, 0.76, 0.9, 0.73, 0.84, 0.87, 0.59],
            "svm precision": [0.5101703534, 0.4190767974, 0.4876253133, 0.3176814585, 0.4737790301,
0.4521113481, 0.5634337068, 0.6595238095, 0.5308305486, 0.5710148769, 0.5327420424, 0.6641981181,
0.2231617647, 0.4664249685, 0.4975759535, 0.5254765843, 0.4693768038, 0.4461635587, 0.5699236425,
0.4368844697, 0.4897829666, 0.5962797619, 0.4896214467, 0.7016369048, 0.6477011494, 0.3824404762,
0.5818976222, 0.5806051587, 0.3748214286],
            "knn accuracy": [0.53, 0.61, 0.79, 0.73, 0.58, 0.69, 0.73, 0.76, 0.75, 0.7, 0.55, 0.68,
0.46, 0.73, 0.7, 0.85, 0.64, 0.51, 0.69, 0.76, 0.47, 0.75, 0.69, 0.75, 0.82, 0.75, 0.53, 0.73, 0.55],
            "knn precision": [0.345949793, 0.3362643678, 0.4759029928, 0.4204906205, 0.3696256039,
0.3583333333, 0.4039726721, 0.3592101648, 0.4251248613, 0.462359944, 0.4101686508, 0.4312298224,
0.1683941059, 0.4071526151, 0.3907634033, 0.699025974, 0.3906504065, 0.4779929577, 0.3662004662,
0.5078242836, 0.3195684524, 0.4268802411, 0.3530961792, 0.5194128788, 0.5146126761, 0.4420405983,
0.3303951679, 0.4701388889, 0.2574142157]}, 
      "c": {"svm accuracy": [0.84, 0.85, 0.9, 0.87, 0.87, 0.95, 0.88, 0.94, 0.9, 0.94, 0.84, 0.9, 0.79,
0.9, 0.91, 0.9, 0.87, 0.92, 0.97, 0.91, 0.85, 0.91, 0.83, 0.85, 0.92, 0.9, 0.9, 0.96, 0.75],
            "svm precision": [0.7588908981, 0.775, 0.8576998051, 0.834717608, 0.834717608, 0.93125,
0.8341601701, 0.9095840868, 0.8862745098, 0.9404677534, 0.7588908981, 0.8576998051, 0.6647727273,
0.8493068113, 0.86875, 0.8695960312, 0.8024475524, 0.890188434, 0.9817073171, 0.8552631579,
0.7733100233, 0.8607226107, 0.7445799458, 0.7784552846, 0.9050318923, 0.8576998051, 0.8576998051,
0.955165692, 0.61875],
            "knn accuracy": [0.8181818182, 0.8181818182, 0.8181818182, 0.8080808081, 0.8282828283,
0.8686868687, 0.8787878788, 0.9191919192, 0.8282828283, 0.8383838384, 0.797979798, 0.8282828283,
0.8080808081, 0.8686868687, 0.8181818182, 0.8686868687, 0.8080808081, 0.8181818182, 0.8787878788,
0.8181818182, 0.8080808081, 0.8585858586, 0.8282828283, 0.8080808081, 0.8282828283, 0.8686868687,
0.8181818182, 0.8585858586, 0.797979798],
            "knn precision": [0.9072164948, 0.9072164948, 0.9072164948, 0.9030612245, 0.9114583333,
0.9293478261, 0.9340659341, 0.9540229885, 0.9114583333, 0.8360215054, 0.6520618557, 0.9114583333,
0.7395833333, 0.9293478261, 0.9072164948, 0.9293478261, 0.9030612245, 0.9072164948, 0.9340659341,
0.9072164948, 0.9030612245, 0.9247311828, 0.9114583333, 0.9030612245, 0.9114583333, 0.9293478261,
0.9072164948, 0.8325842697, 0.6552631579]}, 
      "d": {"svm accuracy": [0.4848484848, 0.5555555556, 0.6868686869, 0.5656565657, 0.6060606061,
0.5252525253, 0.6868686869, 0.696969697, 0.6060606061, 0.6363636364, 0.6666666667, 0.6262626263,
0.1919191919, 0.6464646465, 0.6161616162, 0.6262626263, 0.5252525253, 0.595959596, 0.6565656566,
0.6666666667, 0.4848484848, 0.7070707071, 0.5555555556, 0.6565656566, 0.7575757576, 0.5353535354,
0.6161616162, 0.7070707071, 0.3333333333],
            "svm precision": [0.3703703704, 0.4315608466, 0.5596646185, 0.5070060208, 0.4676245211,
0.4187566138, 0.6034482759, 0.6203571429, 0.5054689755, 0.5615608466, 0.5786706349, 0.5413793103,
0.1842063492, 0.5003456221, 0.5203149002, 0.525921659, 0.386687148, 0.4698941799, 0.5558730159,
0.5708730159, 0.3678391053, 0.5978878648, 0.3953612479, 0.5863300493, 0.6082949309, 0.3923963134,
0.5448823207, 0.6119047619, 0.2868815708],
            "knn accuracy": [0.2929292929, 0.3535353535, 0.3838383838, 0.2626262626, 0.2727272727,
0.3636363636, 0.5555555556, 0.5353535354, 0.4242424242, 0.303030303, 0.4242424242, 0.4747474747,
0.06060606061, 0.4848484848, 0.3535353535, 0.4242424242, 0.2828282828, 0.3434343434, 0.5252525253,
0.4242424242, 0.2525252525, 0.5656565657, 0.202020202, 0.3333333333, 0.5656565657, 0.4141414141,
0.3333333333, 0.5252525253, 0.2424242424],
            "knn precision": [0.2035476623, 0.4331691297, 0.3462876073, 0.3235188106, 0.3486774241,
0.3805850083, 0.5431034483, 0.473015873, 0.4319537742, 0.348316913, 0.4820507079, 0.4416095524,
0.06396103896, 0.4213464696, 0.3061725631, 0.5714285714, 0.2192620526, 0.3703812728, 0.4790801378,
0.4752739909, 0.2608136721, 0.5030952381, 0.1717109921, 0.3508570095, 0.5288050016, 0.4521570384,
0.3676058222, 0.50591133, 0.2467261905]}}
with open("unnormalizedft1.txt", "w") as o:
  o.write("B on B" + "\n")
  o.write("k = 2" + "\n")
  for category in scores2["b unnormalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores2["b unnormalized"][category], performance["b"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores2["b unnormalized"][category], performance["b"]["svm precision"])) 
    + "\n")
  o.write("k = 3" + "\n")
  for category in scores3["b unnormalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores3["b unnormalized"][category], performance["b"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores3["b unnormalized"][category], performance["b"]["svm precision"])) 
    + "\n")
  o.write("k = 4" + "\n")
  for category in scores4["b unnormalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores4["b unnormalized"][category], performance["b"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores4["b unnormalized"][category], performance["b"]["svm precision"])) 
    + "\n")
  o.write("B on C" + "\n")
  o.write("k = 2" + "\n")
  for category in scores2["b unnormalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores2["b unnormalized"][category], performance["c"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores2["b unnormalized"][category], performance["c"]["svm precision"])) 
    + "\n")
  o.write("k = 3" + "\n")
  for category in scores3["b unnormalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores3["b unnormalized"][category], performance["c"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores3["b unnormalized"][category], performance["c"]["svm precision"])) 
    + "\n")
  o.write("k = 4" + "\n")
  for category in scores4["b unnormalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores4["b unnormalized"][category], performance["c"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores4["b unnormalized"][category], performance["c"]["svm precision"])) 
    + "\n")
  o.write("B on D" + "\n")
  o.write("k = 2" + "\n")
  for category in scores2["b unnormalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores2["b unnormalized"][category], performance["d"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores2["b unnormalized"][category], performance["d"]["svm precision"]))
    + "\n") 
  o.write("k = 3" + "\n")
  for category in scores3["b unnormalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores3["b unnormalized"][category], performance["d"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores3["b unnormalized"][category], performance["d"]["svm precision"])) 
    + "\n")
  o.write("k = 4" + "\n")
  for category in scores4["b unnormalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores4["b unnormalized"][category], performance["d"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores4["b unnormalized"][category], performance["d"]["svm precision"])) 
    + "\n")
  # C
  o.write("C on B" + "\n")
  o.write("k = 2" + "\n")
  for category in scores2["c unnormalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores2["c unnormalized"][category], performance["b"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores2["c unnormalized"][category], performance["b"]["svm precision"])) 
    + "\n")
  o.write("k = 3" + "\n")
  for category in scores3["c unnormalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores3["c unnormalized"][category], performance["b"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores3["c unnormalized"][category], performance["b"]["svm precision"])) 
    + "\n")
  o.write("k = 4" + "\n")
  for category in scores4["c unnormalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores4["c unnormalized"][category], performance["b"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores4["c unnormalized"][category], performance["b"]["svm precision"])) 
    + "\n")
  o.write("C on C" + "\n")
  o.write("k = 2" + "\n")
  for category in scores2["c unnormalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores2["c unnormalized"][category], performance["c"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores2["c unnormalized"][category], performance["c"]["svm precision"])) 
    + "\n")
  o.write("k = 3" + "\n")
  for category in scores3["c unnormalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores3["c unnormalized"][category], performance["c"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores3["c unnormalized"][category], performance["c"]["svm precision"])) 
    + "\n")
  o.write("k = 4" + "\n")
  for category in scores4["c unnormalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores4["c unnormalized"][category], performance["c"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores4["c unnormalized"][category], performance["c"]["svm precision"])) 
    + "\n")
  o.write("C on D" + "\n")
  o.write("k = 2" + "\n")
  for category in scores2["c unnormalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores2["c unnormalized"][category], performance["d"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores2["c unnormalized"][category], performance["d"]["svm precision"])) 
    + "\n")
  o.write("k = 3" + "\n")
  for category in scores3["c unnormalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores3["c unnormalized"][category], performance["d"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores3["c unnormalized"][category], performance["d"]["svm precision"])) 
    + "\n")
  o.write("k = 4" + "\n")
  for category in scores4["c unnormalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores4["c unnormalized"][category], performance["d"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores4["c unnormalized"][category], performance["d"]["svm precision"])) 
    + "\n")
  # D
  o.write("D on B" + "\n")
  o.write("k = 2" + "\n")
  for category in scores2["d unnormalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores2["d unnormalized"][category], performance["b"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores2["d unnormalized"][category], performance["b"]["svm precision"])) 
    + "\n")
  o.write("k = 3" + "\n")
  for category in scores3["d unnormalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores3["d unnormalized"][category], performance["b"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores3["d unnormalized"][category], performance["b"]["svm precision"])) 
    + "\n")
  o.write("k = 4" + "\n")
  for category in scores4["d unnormalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores4["d unnormalized"][category], performance["b"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores4["d unnormalized"][category], performance["b"]["svm precision"])) 
    + "\n")
  o.write("D on C" + "\n")
  o.write("k = 2" + "\n")
  for category in scores2["d unnormalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores2["d unnormalized"][category], performance["c"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores2["d unnormalized"][category], performance["c"]["svm precision"])) 
    + "\n")
  o.write("k = 3" + "\n")
  for category in scores3["d unnormalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores3["d unnormalized"][category], performance["c"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores3["d unnormalized"][category], performance["c"]["svm precision"])) 
    + "\n")
  o.write("k = 4" + "\n")
  for category in scores4["d unnormalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores4["d unnormalized"][category], performance["c"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores4["d unnormalized"][category], performance["c"]["svm precision"])) 
    + "\n")
  o.write("D on D" + "\n")
  o.write("k = 2" + "\n")
  for category in scores2["d unnormalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores2["d unnormalized"][category], performance["d"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores2["d unnormalized"][category], performance["d"]["svm precision"])) 
    + "\n")
  o.write("k = 3" + "\n")
  for category in scores3["d unnormalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores3["d unnormalized"][category], performance["d"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores3["d unnormalized"][category], performance["d"]["svm precision"])) 
    + "\n")
  o.write("k = 4" + "\n")
  for category in scores4["d unnormalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores4["d unnormalized"][category], performance["d"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores4["d unnormalized"][category], performance["d"]["svm precision"])) 
    + "\n")


with open("normalizedft1.txt", "w") as o:
  o.write("B on B" + "\n")
  o.write("k = 2" + "\n")
  for category in scores2["b normalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores2["b normalized"][category], performance["b"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores2["b normalized"][category], performance["b"]["svm precision"])) 
    + "\n")
  o.write("k = 3" + "\n")
  for category in scores3["b normalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores3["b normalized"][category], performance["b"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores3["b normalized"][category], performance["b"]["svm precision"])) 
    + "\n")
  o.write("k = 4" + "\n")
  for category in scores4["b normalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores4["b normalized"][category], performance["b"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores4["b normalized"][category], performance["b"]["svm precision"])) 
    + "\n")
  o.write("B on C" + "\n")
  o.write("k = 2" + "\n")
  for category in scores2["b normalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores2["b normalized"][category], performance["c"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores2["b normalized"][category], performance["c"]["svm precision"])) 
    + "\n")
  o.write("k = 3" + "\n")
  for category in scores3["b normalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores3["b normalized"][category], performance["c"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores3["b normalized"][category], performance["c"]["svm precision"])) 
    + "\n")
  o.write("k = 4" + "\n")
  for category in scores4["b normalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores4["b normalized"][category], performance["c"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores4["b normalized"][category], performance["c"]["svm precision"])) 
    + "\n")
  o.write("B on D" + "\n")
  o.write("k = 2" + "\n")
  for category in scores2["b normalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores2["b normalized"][category], performance["d"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores2["b normalized"][category], performance["d"]["svm precision"])) 
    + "\n")
  o.write("k = 3" + "\n")
  for category in scores3["b normalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores3["b normalized"][category], performance["d"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores3["b normalized"][category], performance["d"]["svm precision"])) 
    + "\n")
  o.write("k = 4" + "\n")
  for category in scores4["b normalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores4["b normalized"][category], performance["d"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores4["b normalized"][category], performance["d"]["svm precision"])) 
    + "\n")
  # C
  o.write("C on B" + "\n")
  o.write("k = 2" + "\n")
  for category in scores2["c normalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores2["c normalized"][category], performance["b"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores2["c normalized"][category], performance["b"]["svm precision"])) 
    + "\n")
  o.write("k = 3" + "\n")
  for category in scores3["c normalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores3["c normalized"][category], performance["b"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores3["c normalized"][category], performance["b"]["svm precision"])) 
    + "\n")
  o.write("k = 4" + "\n")
  for category in scores4["c normalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores4["c normalized"][category], performance["b"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores4["c normalized"][category], performance["b"]["svm precision"])) 
    + "\n")
  o.write("C on C" + "\n")
  o.write("k = 2" + "\n")
  for category in scores2["c normalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores2["c normalized"][category], performance["c"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores2["c normalized"][category], performance["c"]["svm precision"])) 
    + "\n")
  o.write("k = 3" + "\n")
  for category in scores3["c normalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores3["c normalized"][category], performance["c"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores3["c normalized"][category], performance["c"]["svm precision"])) 
    + "\n")
  o.write("k = 4" + "\n")
  for category in scores4["c normalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores4["c normalized"][category], performance["c"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores4["c normalized"][category], performance["c"]["svm precision"])) 
    + "\n")
  o.write("C on D" + "\n")
  o.write("k = 2" + "\n")
  for category in scores2["c normalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores2["c normalized"][category], performance["d"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores2["c normalized"][category], performance["d"]["svm precision"])) 
    + "\n")
  o.write("k = 3" + "\n")
  for category in scores3["c normalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores3["c normalized"][category], performance["d"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores3["c normalized"][category], performance["d"]["svm precision"])) 
    + "\n")
  o.write("k = 4" + "\n")
  for category in scores4["c normalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores4["c normalized"][category], performance["d"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores4["c normalized"][category], performance["d"]["svm precision"])) 
    + "\n")
  # D
  o.write("D on B" + "\n")
  o.write("k = 2" + "\n")
  for category in scores2["d normalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores2["d normalized"][category], performance["b"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores2["d normalized"][category], performance["b"]["svm precision"])) 
    + "\n")
  o.write("k = 3" + "\n")
  for category in scores3["d normalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores3["d normalized"][category], performance["b"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores3["d normalized"][category], performance["b"]["svm precision"])) 
    + "\n")
  o.write("k = 4" + "\n")
  for category in scores4["d normalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores4["d normalized"][category], performance["b"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores4["d normalized"][category], performance["b"]["svm precision"])) 
    + "\n")
  o.write("D on C" + "\n")
  o.write("k = 2" + "\n")
  for category in scores2["d normalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores2["d normalized"][category], performance["c"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores2["d normalized"][category], performance["c"]["svm precision"])) 
    + "\n")
  o.write("k = 3" + "\n")
  for category in scores3["d normalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores3["d normalized"][category], performance["c"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores3["d normalized"][category], performance["c"]["svm precision"])) 
    + "\n")
  o.write("k = 4" + "\n")
  for category in scores4["d normalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores4["d normalized"][category], performance["c"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores4["d normalized"][category], performance["c"]["svm precision"])) 
    + "\n")
  o.write("D on D" + "\n")
  o.write("k = 2" + "\n")
  for category in scores2["d normalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores2["d normalized"][category], performance["d"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores2["d normalized"][category], performance["d"]["svm precision"])) 
    + "\n")
  o.write("k = 3" + "\n")
  for category in scores3["d normalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores3["d normalized"][category], performance["d"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores3["d normalized"][category], performance["d"]["svm precision"])) 
    + "\n")
  o.write("k = 4" + "\n")
  for category in scores4["d normalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores4["d normalized"][category], performance["d"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores4["d normalized"][category], performance["d"]["svm precision"])) 
    + "\n")

# %%
# muse, 1 trial
from scipy import stats
import csv
scores2 = {"b normalized": {}, "c normalized": {}, "d normalized": {},
          "b unnormalized": {}, "c unnormalized": {}, "d unnormalized": {}}
scores3 = {"b normalized": {}, "c normalized": {}, "d normalized": {},
          "b unnormalized": {}, "c unnormalized": {}, "d unnormalized": {}}
scores4 = {"b normalized": {}, "c normalized": {}, "d normalized": {},
          "b unnormalized": {}, "c unnormalized": {}, "d unnormalized": {}}
conversion = {"du": "d unnormalized", "dn": "d normalized",
              "cu": "c unnormalized", "cn": "c normalized",
              "bu": "b unnormalized", "bn": "b normalized"}
for k in conversion.keys():
  with open(k + "2.csv", newline="") as csvfile:
    reader = csv.reader(csvfile)
    rows = [row for row in reader]
    for i in range(len(rows[0][1:])):
      scores2[conversion[k]][rows[0][i + 1]] = [float(score[i + 1]) for score in rows[1:]]
for k in conversion.keys():
  with open(k + "3.csv", newline="") as csvfile:
    reader = csv.reader(csvfile)
    rows = [row for row in reader]
    for i in range(len(rows[0][1:])):
      scores3[conversion[k]][rows[0][i + 1]] = [float(score[i + 1]) for score in rows[1:]]
for k in conversion.keys():
  with open(k + "4.csv", newline="") as csvfile:
    reader = csv.reader(csvfile)
    rows = [row for row in reader]
    for i in range(len(rows[0][1:])):
      scores4[conversion[k]][rows[0][i + 1]] = [float(score[i + 1]) for score in rows[1:]]
performance = {"b": {"svm accuracy": [0.78, 0.73, 0.84, 0.73, 0.73, 0.72, 0.81, 0.88, 0.77, 0.74,
0.86, 0.75, 0.58, 0.8, 0.84, 0.81, 0.74, 0.79, 0.74, 0.87, 0.71, 0.77, 0.65, 0.78, 0.86, 0.68, 0.85,
0.76, 0.75],
            "svm precision": [0.5642984467, 0.6867623604, 0.7246543779, 0.5778420523, 0.6814058957,
0.6815560027, 0.7091606134, 0.7761204482, 0.67281528, 0.6883089133, 0.6203520164, 0.4573027719,
0.3929909042, 0.6201178979, 0.7377660742, 0.7636904762, 0.5763038549, 0.6192546584, 0.5389527642,
0.7401837928, 0.5056514914, 0.7341836735, 0.6001141715, 0.7505175983, 0.7512531328, 0.5093281148,
0.7440812483, 0.6865481267, 0.5440361219]}, 
      "c": {"svm accuracy": [0.96, 0.95, 0.96, 0.9, 0.92, 0.97, 0.97, 0.96, 0.92, 0.91, 0.96, 0.94,
0.85, 0.97, 0.98, 0.97, 0.94, 0.94, 0.92, 0.95, 0.94, 0.92, 0.94, 0.92, 0.99, 0.89, 0.94, 0.92, 0.9],
            "svm precision": [0.9772727273, 0.9719101124, 0.9772727273, 0.8555555556, 0.8825757576,
0.9827586207, 0.9827586207, 0.9772727273, 0.9111111111, 0.8697650664, 0.9468438538, 0.9666666667,
0.7611683849, 0.9549019608, 0.988372093, 0.9351523742, 0.9053156146, 0.9299242424, 0.9565217391,
0.9156862745, 0.9299242424, 0.9565217391, 0.9666666667, 0.9111111111, 0.9941176471, 0.8748079877,
0.9666666667, 0.9565217391, 0.8352272727]}, 
      "d": {"svm accuracy": [0.47, 0.5, 0.57, 0.47, 0.61, 0.45, 0.58, 0.65, 0.42, 0.56, 0.61, 0.52,
0.25, 0.51, 0.62, 0.59, 0.42, 0.57, 0.5, 0.62, 0.46, 0.47, 0.39, 0.45, 0.63, 0.52, 0.52, 0.43, 0.49],
            "svm precision": [0.3824600687, 0.4173623995, 0.574137931, 0.3640059647, 0.440138597,
0.4229064039, 0.5374832064, 0.5524630542, 0.3400088417, 0.5321428571, 0.5448554422, 0.4771441202,
0.2788919414, 0.4318007663, 0.558106576, 0.5306986117, 0.4111166611, 0.5801870748, 0.4551450465,
0.5027910053, 0.3240968801, 0.4850122558, 0.3175287356, 0.4845155993, 0.6277367269, 0.3714760617,
0.4754789272, 0.3678633627, 0.4845427561]}}
with open("unnormalizedmuse1.txt", "w") as o:
  o.write("B on B" + "\n")
  o.write("k = 2" + "\n")
  for category in scores2["b unnormalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores2["b unnormalized"][category], performance["b"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores2["b unnormalized"][category], performance["b"]["svm precision"])) 
    + "\n")
  o.write("k = 3" + "\n")
  for category in scores3["b unnormalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores3["b unnormalized"][category], performance["b"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores3["b unnormalized"][category], performance["b"]["svm precision"])) 
    + "\n")
  o.write("k = 4" + "\n")
  for category in scores4["b unnormalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores4["b unnormalized"][category], performance["b"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores4["b unnormalized"][category], performance["b"]["svm precision"])) 
    + "\n")
  o.write("B on C" + "\n")
  o.write("k = 2" + "\n")
  for category in scores2["b unnormalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores2["b unnormalized"][category], performance["c"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores2["b unnormalized"][category], performance["c"]["svm precision"])) 
    + "\n")
  o.write("k = 3" + "\n")
  for category in scores3["b unnormalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores3["b unnormalized"][category], performance["c"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores3["b unnormalized"][category], performance["c"]["svm precision"])) 
    + "\n")
  o.write("k = 4" + "\n")
  for category in scores4["b unnormalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores4["b unnormalized"][category], performance["c"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores4["b unnormalized"][category], performance["c"]["svm precision"])) 
    + "\n")
  o.write("B on D" + "\n")
  o.write("k = 2" + "\n")
  for category in scores2["b unnormalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores2["b unnormalized"][category], performance["d"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores2["b unnormalized"][category], performance["d"]["svm precision"]))
    + "\n") 
  o.write("k = 3" + "\n")
  for category in scores3["b unnormalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores3["b unnormalized"][category], performance["d"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores3["b unnormalized"][category], performance["d"]["svm precision"])) 
    + "\n")
  o.write("k = 4" + "\n")
  for category in scores4["b unnormalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores4["b unnormalized"][category], performance["d"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores4["b unnormalized"][category], performance["d"]["svm precision"])) 
    + "\n")
  # C
  o.write("C on B" + "\n")
  o.write("k = 2" + "\n")
  for category in scores2["c unnormalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores2["c unnormalized"][category], performance["b"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores2["c unnormalized"][category], performance["b"]["svm precision"])) 
    + "\n")
  o.write("k = 3" + "\n")
  for category in scores3["c unnormalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores3["c unnormalized"][category], performance["b"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores3["c unnormalized"][category], performance["b"]["svm precision"])) 
    + "\n")
  o.write("k = 4" + "\n")
  for category in scores4["c unnormalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores4["c unnormalized"][category], performance["b"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores4["c unnormalized"][category], performance["b"]["svm precision"])) 
    + "\n")
  o.write("C on C" + "\n")
  o.write("k = 2" + "\n")
  for category in scores2["c unnormalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores2["c unnormalized"][category], performance["c"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores2["c unnormalized"][category], performance["c"]["svm precision"])) 
    + "\n")
  o.write("k = 3" + "\n")
  for category in scores3["c unnormalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores3["c unnormalized"][category], performance["c"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores3["c unnormalized"][category], performance["c"]["svm precision"])) 
    + "\n")
  o.write("k = 4" + "\n")
  for category in scores4["c unnormalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores4["c unnormalized"][category], performance["c"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores4["c unnormalized"][category], performance["c"]["svm precision"])) 
    + "\n")
  o.write("C on D" + "\n")
  o.write("k = 2" + "\n")
  for category in scores2["c unnormalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores2["c unnormalized"][category], performance["d"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores2["c unnormalized"][category], performance["d"]["svm precision"])) 
    + "\n")
  o.write("k = 3" + "\n")
  for category in scores3["c unnormalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores3["c unnormalized"][category], performance["d"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores3["c unnormalized"][category], performance["d"]["svm precision"])) 
    + "\n")
  o.write("k = 4" + "\n")
  for category in scores4["c unnormalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores4["c unnormalized"][category], performance["d"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores4["c unnormalized"][category], performance["d"]["svm precision"])) 
    + "\n")
  # D
  o.write("D on B" + "\n")
  o.write("k = 2" + "\n")
  for category in scores2["d unnormalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores2["d unnormalized"][category], performance["b"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores2["d unnormalized"][category], performance["b"]["svm precision"])) 
    + "\n")
  o.write("k = 3" + "\n")
  for category in scores3["d unnormalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores3["d unnormalized"][category], performance["b"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores3["d unnormalized"][category], performance["b"]["svm precision"])) 
    + "\n")
  o.write("k = 4" + "\n")
  for category in scores4["d unnormalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores4["d unnormalized"][category], performance["b"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores4["d unnormalized"][category], performance["b"]["svm precision"])) 
    + "\n")
  o.write("D on C" + "\n")
  o.write("k = 2" + "\n")
  for category in scores2["d unnormalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores2["d unnormalized"][category], performance["c"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores2["d unnormalized"][category], performance["c"]["svm precision"])) 
    + "\n")
  o.write("k = 3" + "\n")
  for category in scores3["d unnormalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores3["d unnormalized"][category], performance["c"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores3["d unnormalized"][category], performance["c"]["svm precision"])) 
    + "\n")
  o.write("k = 4" + "\n")
  for category in scores4["d unnormalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores4["d unnormalized"][category], performance["c"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores4["d unnormalized"][category], performance["c"]["svm precision"])) 
    + "\n")
  o.write("D on D" + "\n")
  o.write("k = 2" + "\n")
  for category in scores2["d unnormalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores2["d unnormalized"][category], performance["d"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores2["d unnormalized"][category], performance["d"]["svm precision"])) 
    + "\n")
  o.write("k = 3" + "\n")
  for category in scores3["d unnormalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores3["d unnormalized"][category], performance["d"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores3["d unnormalized"][category], performance["d"]["svm precision"])) 
    + "\n")
  o.write("k = 4" + "\n")
  for category in scores4["d unnormalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores4["d unnormalized"][category], performance["d"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores4["d unnormalized"][category], performance["d"]["svm precision"])) 
    + "\n")


with open("normalizedmuse1.txt", "w") as o:
  o.write("B on B" + "\n")
  o.write("k = 2" + "\n")
  for category in scores2["b normalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores2["b normalized"][category], performance["b"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores2["b normalized"][category], performance["b"]["svm precision"])) 
    + "\n")
  o.write("k = 3" + "\n")
  for category in scores3["b normalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores3["b normalized"][category], performance["b"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores3["b normalized"][category], performance["b"]["svm precision"])) 
    + "\n")
  o.write("k = 4" + "\n")
  for category in scores4["b normalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores4["b normalized"][category], performance["b"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores4["b normalized"][category], performance["b"]["svm precision"])) 
    + "\n")
  o.write("B on C" + "\n")
  o.write("k = 2" + "\n")
  for category in scores2["b normalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores2["b normalized"][category], performance["c"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores2["b normalized"][category], performance["c"]["svm precision"])) 
    + "\n")
  o.write("k = 3" + "\n")
  for category in scores3["b normalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores3["b normalized"][category], performance["c"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores3["b normalized"][category], performance["c"]["svm precision"])) 
    + "\n")
  o.write("k = 4" + "\n")
  for category in scores4["b normalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores4["b normalized"][category], performance["c"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores4["b normalized"][category], performance["c"]["svm precision"])) 
    + "\n")
  o.write("B on D" + "\n")
  o.write("k = 2" + "\n")
  for category in scores2["b normalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores2["b normalized"][category], performance["d"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores2["b normalized"][category], performance["d"]["svm precision"])) 
    + "\n")
  o.write("k = 3" + "\n")
  for category in scores3["b normalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores3["b normalized"][category], performance["d"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores3["b normalized"][category], performance["d"]["svm precision"])) 
    + "\n")
  o.write("k = 4" + "\n")
  for category in scores4["b normalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores4["b normalized"][category], performance["d"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores4["b normalized"][category], performance["d"]["svm precision"])) 
    + "\n")
  # C
  o.write("C on B" + "\n")
  o.write("k = 2" + "\n")
  for category in scores2["c normalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores2["c normalized"][category], performance["b"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores2["c normalized"][category], performance["b"]["svm precision"])) 
    + "\n")
  o.write("k = 3" + "\n")
  for category in scores3["c normalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores3["c normalized"][category], performance["b"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores3["c normalized"][category], performance["b"]["svm precision"])) 
    + "\n")
  o.write("k = 4" + "\n")
  for category in scores4["c normalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores4["c normalized"][category], performance["b"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores4["c normalized"][category], performance["b"]["svm precision"])) 
    + "\n")
  o.write("C on C" + "\n")
  o.write("k = 2" + "\n")
  for category in scores2["c normalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores2["c normalized"][category], performance["c"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores2["c normalized"][category], performance["c"]["svm precision"])) 
    + "\n")
  o.write("k = 3" + "\n")
  for category in scores3["c normalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores3["c normalized"][category], performance["c"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores3["c normalized"][category], performance["c"]["svm precision"])) 
    + "\n")
  o.write("k = 4" + "\n")
  for category in scores4["c normalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores4["c normalized"][category], performance["c"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores4["c normalized"][category], performance["c"]["svm precision"])) 
    + "\n")
  o.write("C on D" + "\n")
  o.write("k = 2" + "\n")
  for category in scores2["c normalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores2["c normalized"][category], performance["d"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores2["c normalized"][category], performance["d"]["svm precision"])) 
    + "\n")
  o.write("k = 3" + "\n")
  for category in scores3["c normalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores3["c normalized"][category], performance["d"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores3["c normalized"][category], performance["d"]["svm precision"])) 
    + "\n")
  o.write("k = 4" + "\n")
  for category in scores4["c normalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores4["c normalized"][category], performance["d"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores4["c normalized"][category], performance["d"]["svm precision"])) 
    + "\n")
  # D
  o.write("D on B" + "\n")
  o.write("k = 2" + "\n")
  for category in scores2["d normalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores2["d normalized"][category], performance["b"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores2["d normalized"][category], performance["b"]["svm precision"])) 
    + "\n")
  o.write("k = 3" + "\n")
  for category in scores3["d normalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores3["d normalized"][category], performance["b"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores3["d normalized"][category], performance["b"]["svm precision"])) 
    + "\n")
  o.write("k = 4" + "\n")
  for category in scores4["d normalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores4["d normalized"][category], performance["b"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores4["d normalized"][category], performance["b"]["svm precision"])) 
    + "\n")
  o.write("D on C" + "\n")
  o.write("k = 2" + "\n")
  for category in scores2["d normalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores2["d normalized"][category], performance["c"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores2["d normalized"][category], performance["c"]["svm precision"])) 
    + "\n")
  o.write("k = 3" + "\n")
  for category in scores3["d normalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores3["d normalized"][category], performance["c"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores3["d normalized"][category], performance["c"]["svm precision"])) 
    + "\n")
  o.write("k = 4" + "\n")
  for category in scores4["d normalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores4["d normalized"][category], performance["c"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores4["d normalized"][category], performance["c"]["svm precision"])) 
    + "\n")
  o.write("D on D" + "\n")
  o.write("k = 2" + "\n")
  for category in scores2["d normalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores2["d normalized"][category], performance["d"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores2["d normalized"][category], performance["d"]["svm precision"])) 
    + "\n")
  o.write("k = 3" + "\n")
  for category in scores3["d normalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores3["d normalized"][category], performance["d"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores3["d normalized"][category], performance["d"]["svm precision"])) 
    + "\n")
  o.write("k = 4" + "\n")
  for category in scores4["d normalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores4["d normalized"][category], performance["d"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores4["d normalized"][category], performance["d"]["svm precision"])) 
    + "\n")

# %%
# fasttext, 30 trials
from scipy import stats
import csv
scores2 = {"b normalized": {}, "c normalized": {}, "d normalized": {},
          "b unnormalized": {}, "c unnormalized": {}, "d unnormalized": {}}
scores3 = {"b normalized": {}, "c normalized": {}, "d normalized": {},
          "b unnormalized": {}, "c unnormalized": {}, "d unnormalized": {}}
scores4 = {"b normalized": {}, "c normalized": {}, "d normalized": {},
          "b unnormalized": {}, "c unnormalized": {}, "d unnormalized": {}}
conversion = {"du": "d unnormalized", "dn": "d normalized",
              "cu": "c unnormalized", "cn": "c normalized",
              "bu": "b unnormalized", "bn": "b normalized"}
for k in conversion.keys():
  with open(k + "2.csv", newline="") as csvfile:
    reader = csv.reader(csvfile)
    rows = [row for row in reader]
    for i in range(len(rows[0][1:])):
      scores2[conversion[k]][rows[0][i + 1]] = [float(score[i + 1]) for score in rows[1:]]
for k in conversion.keys():
  with open(k + "3.csv", newline="") as csvfile:
    reader = csv.reader(csvfile)
    rows = [row for row in reader]
    for i in range(len(rows[0][1:])):
      scores3[conversion[k]][rows[0][i + 1]] = [float(score[i + 1]) for score in rows[1:]]
for k in conversion.keys():
  with open(k + "4.csv", newline="") as csvfile:
    reader = csv.reader(csvfile)
    rows = [row for row in reader]
    for i in range(len(rows[0][1:])):
      scores4[conversion[k]][rows[0][i + 1]] = [float(score[i + 1]) for score in rows[1:]]
performance = {"b": {"svm accuracy": [0.7673703704, 0.7463299663, 0.8385420875, 0.767037037,
0.7904141414, 0.7205589226, 0.857959596, 0.8713468013, 0.7850942761, 0.7934612795, 0.8285420875,
0.8052188552, 0.48996633, 0.8131481481, 0.7941178451, 0.8037676768, 0.751996633, 0.752020202,
0.8382424242, 0.8248956229, 0.7426599327, 0.864969697, 0.7179259259, 0.7944276094, 0.8863670034,
0.7359393939, 0.8308619529, 0.8342188552, 0.616956229],
            "svm precision": [0.5464727939, 0.5377880621, 0.6534597223, 0.5780594388, 0.5907848568,
0.5226709456, 0.6457177645, 0.7119076314, 0.5749471763, 0.6495865697, 0.6494690692, 0.6160726757,
0.2520649922, 0.5990372326, 0.5808536863, 0.6490800984, 0.5940517202, 0.558948451, 0.6745174116,
0.6733482418, 0.5858530787, 0.681696211, 0.5104926695, 0.6460162671, 0.6971797383, 0.5612774072,
0.6420604534, 0.6527046011, 0.3899390852]}, 
      "c": {"svm accuracy": [0.8763400673, 0.8826801347, 0.9198047138, 0.8780572391, 0.9091077441,
0.872979798, 0.9304747475, 0.9364949495, 0.9070808081, 0.9000942761, 0.9091077441, 0.9001111111,
0.7443232323, 0.9137676768, 0.9137912458, 0.9034074074, 0.8773468013, 0.9047710438, 0.9234848485,
0.9017609428, 0.8783737374, 0.9257946128, 0.8646430976, 0.8753501684, 0.9378552189, 0.8923905724,
0.8863771044, 0.9221380471, 0.8045521886],
            "svm precision": [0.806782194, 0.8114913366, 0.8819106968, 0.8061546368, 0.8572243655,
0.7964645835, 0.8890861172, 0.9037432513, 0.8559372566, 0.8423619914, 0.8566965026, 0.8437733434,
0.5740093462, 0.8612944814, 0.8679272473, 0.8533264654, 0.808455226, 0.8531786127, 0.8861563599,
0.8448151212, 0.8043139448, 0.8869307513, 0.7829614458, 0.8003360301, 0.9045145727, 0.8272563165,
0.8225562593, 0.8822261985, 0.6718035062]}, 
      "d": {"svm accuracy": [0.5157643098, 0.590969697, 0.6291010101, 0.5291212121, 0.5973164983,
0.5461313131, 0.6431043771, 0.6672424242, 0.5789124579, 0.6260808081, 0.6485050505, 0.6107306397,
0.1818619529, 0.6317508418, 0.6258013468, 0.609020202, 0.5251313131, 0.5766329966, 0.6421582492,
0.615026936, 0.5091043771, 0.6665589226, 0.509020202, 0.5735892256, 0.6668956229, 0.5555353535,
0.5966464646, 0.6478316498, 0.3611784512],
            "svm precision": [0.4102556406, 0.4667136909, 0.5446862207, 0.4291789973, 0.4996698388,
0.4405435036, 0.5493448149, 0.5662858518, 0.4758947154, 0.5064977119, 0.5487233569, 0.5242397881,
0.1497843112, 0.4962646326, 0.5227193425, 0.4973395611, 0.4272808454, 0.4628620906, 0.5411724042,
0.5217481426, 0.4136969768, 0.5701962427, 0.3988559828, 0.4897167993, 0.5781504414, 0.4519258581,
0.4956309342, 0.551043068, 0.3077475294]}}
with open("unnormalizedft30.txt", "w") as o:
  o.write("B on B" + "\n")
  o.write("k = 2" + "\n")
  for category in scores2["b unnormalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores2["b unnormalized"][category], performance["b"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores2["b unnormalized"][category], performance["b"]["svm precision"])) 
    + "\n")
  o.write("k = 3" + "\n")
  for category in scores3["b unnormalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores3["b unnormalized"][category], performance["b"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores3["b unnormalized"][category], performance["b"]["svm precision"])) 
    + "\n")
  o.write("k = 4" + "\n")
  for category in scores4["b unnormalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores4["b unnormalized"][category], performance["b"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores4["b unnormalized"][category], performance["b"]["svm precision"])) 
    + "\n")
  o.write("B on C" + "\n")
  o.write("k = 2" + "\n")
  for category in scores2["b unnormalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores2["b unnormalized"][category], performance["c"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores2["b unnormalized"][category], performance["c"]["svm precision"])) 
    + "\n")
  o.write("k = 3" + "\n")
  for category in scores3["b unnormalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores3["b unnormalized"][category], performance["c"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores3["b unnormalized"][category], performance["c"]["svm precision"])) 
    + "\n")
  o.write("k = 4" + "\n")
  for category in scores4["b unnormalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores4["b unnormalized"][category], performance["c"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores4["b unnormalized"][category], performance["c"]["svm precision"])) 
    + "\n")
  o.write("B on D" + "\n")
  o.write("k = 2" + "\n")
  for category in scores2["b unnormalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores2["b unnormalized"][category], performance["d"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores2["b unnormalized"][category], performance["d"]["svm precision"]))
    + "\n") 
  o.write("k = 3" + "\n")
  for category in scores3["b unnormalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores3["b unnormalized"][category], performance["d"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores3["b unnormalized"][category], performance["d"]["svm precision"])) 
    + "\n")
  o.write("k = 4" + "\n")
  for category in scores4["b unnormalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores4["b unnormalized"][category], performance["d"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores4["b unnormalized"][category], performance["d"]["svm precision"])) 
    + "\n")
  # C
  o.write("C on B" + "\n")
  o.write("k = 2" + "\n")
  for category in scores2["c unnormalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores2["c unnormalized"][category], performance["b"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores2["c unnormalized"][category], performance["b"]["svm precision"])) 
    + "\n")
  o.write("k = 3" + "\n")
  for category in scores3["c unnormalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores3["c unnormalized"][category], performance["b"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores3["c unnormalized"][category], performance["b"]["svm precision"])) 
    + "\n")
  o.write("k = 4" + "\n")
  for category in scores4["c unnormalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores4["c unnormalized"][category], performance["b"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores4["c unnormalized"][category], performance["b"]["svm precision"])) 
    + "\n")
  o.write("C on C" + "\n")
  o.write("k = 2" + "\n")
  for category in scores2["c unnormalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores2["c unnormalized"][category], performance["c"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores2["c unnormalized"][category], performance["c"]["svm precision"])) 
    + "\n")
  o.write("k = 3" + "\n")
  for category in scores3["c unnormalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores3["c unnormalized"][category], performance["c"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores3["c unnormalized"][category], performance["c"]["svm precision"])) 
    + "\n")
  o.write("k = 4" + "\n")
  for category in scores4["c unnormalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores4["c unnormalized"][category], performance["c"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores4["c unnormalized"][category], performance["c"]["svm precision"])) 
    + "\n")
  o.write("C on D" + "\n")
  o.write("k = 2" + "\n")
  for category in scores2["c unnormalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores2["c unnormalized"][category], performance["d"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores2["c unnormalized"][category], performance["d"]["svm precision"])) 
    + "\n")
  o.write("k = 3" + "\n")
  for category in scores3["c unnormalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores3["c unnormalized"][category], performance["d"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores3["c unnormalized"][category], performance["d"]["svm precision"])) 
    + "\n")
  o.write("k = 4" + "\n")
  for category in scores4["c unnormalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores4["c unnormalized"][category], performance["d"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores4["c unnormalized"][category], performance["d"]["svm precision"])) 
    + "\n")
  # D
  o.write("D on B" + "\n")
  o.write("k = 2" + "\n")
  for category in scores2["d unnormalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores2["d unnormalized"][category], performance["b"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores2["d unnormalized"][category], performance["b"]["svm precision"])) 
    + "\n")
  o.write("k = 3" + "\n")
  for category in scores3["d unnormalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores3["d unnormalized"][category], performance["b"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores3["d unnormalized"][category], performance["b"]["svm precision"])) 
    + "\n")
  o.write("k = 4" + "\n")
  for category in scores4["d unnormalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores4["d unnormalized"][category], performance["b"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores4["d unnormalized"][category], performance["b"]["svm precision"])) 
    + "\n")
  o.write("D on C" + "\n")
  o.write("k = 2" + "\n")
  for category in scores2["d unnormalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores2["d unnormalized"][category], performance["c"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores2["d unnormalized"][category], performance["c"]["svm precision"])) 
    + "\n")
  o.write("k = 3" + "\n")
  for category in scores3["d unnormalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores3["d unnormalized"][category], performance["c"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores3["d unnormalized"][category], performance["c"]["svm precision"])) 
    + "\n")
  o.write("k = 4" + "\n")
  for category in scores4["d unnormalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores4["d unnormalized"][category], performance["c"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores4["d unnormalized"][category], performance["c"]["svm precision"])) 
    + "\n")
  o.write("D on D" + "\n")
  o.write("k = 2" + "\n")
  for category in scores2["d unnormalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores2["d unnormalized"][category], performance["d"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores2["d unnormalized"][category], performance["d"]["svm precision"])) 
    + "\n")
  o.write("k = 3" + "\n")
  for category in scores3["d unnormalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores3["d unnormalized"][category], performance["d"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores3["d unnormalized"][category], performance["d"]["svm precision"])) 
    + "\n")
  o.write("k = 4" + "\n")
  for category in scores4["d unnormalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores4["d unnormalized"][category], performance["d"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores4["d unnormalized"][category], performance["d"]["svm precision"])) 
    + "\n")


with open("normalizedft30.txt", "w") as o:
  o.write("B on B" + "\n")
  o.write("k = 2" + "\n")
  for category in scores2["b normalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores2["b normalized"][category], performance["b"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores2["b normalized"][category], performance["b"]["svm precision"])) 
    + "\n")
  o.write("k = 3" + "\n")
  for category in scores3["b normalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores3["b normalized"][category], performance["b"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores3["b normalized"][category], performance["b"]["svm precision"])) 
    + "\n")
  o.write("k = 4" + "\n")
  for category in scores4["b normalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores4["b normalized"][category], performance["b"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores4["b normalized"][category], performance["b"]["svm precision"])) 
    + "\n")
  o.write("B on C" + "\n")
  o.write("k = 2" + "\n")
  for category in scores2["b normalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores2["b normalized"][category], performance["c"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores2["b normalized"][category], performance["c"]["svm precision"])) 
    + "\n")
  o.write("k = 3" + "\n")
  for category in scores3["b normalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores3["b normalized"][category], performance["c"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores3["b normalized"][category], performance["c"]["svm precision"])) 
    + "\n")
  o.write("k = 4" + "\n")
  for category in scores4["b normalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores4["b normalized"][category], performance["c"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores4["b normalized"][category], performance["c"]["svm precision"])) 
    + "\n")
  o.write("B on D" + "\n")
  o.write("k = 2" + "\n")
  for category in scores2["b normalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores2["b normalized"][category], performance["d"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores2["b normalized"][category], performance["d"]["svm precision"])) 
    + "\n")
  o.write("k = 3" + "\n")
  for category in scores3["b normalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores3["b normalized"][category], performance["d"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores3["b normalized"][category], performance["d"]["svm precision"])) 
    + "\n")
  o.write("k = 4" + "\n")
  for category in scores4["b normalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores4["b normalized"][category], performance["d"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores4["b normalized"][category], performance["d"]["svm precision"])) 
    + "\n")
  # C
  o.write("C on B" + "\n")
  o.write("k = 2" + "\n")
  for category in scores2["c normalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores2["c normalized"][category], performance["b"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores2["c normalized"][category], performance["b"]["svm precision"])) 
    + "\n")
  o.write("k = 3" + "\n")
  for category in scores3["c normalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores3["c normalized"][category], performance["b"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores3["c normalized"][category], performance["b"]["svm precision"])) 
    + "\n")
  o.write("k = 4" + "\n")
  for category in scores4["c normalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores4["c normalized"][category], performance["b"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores4["c normalized"][category], performance["b"]["svm precision"])) 
    + "\n")
  o.write("C on C" + "\n")
  o.write("k = 2" + "\n")
  for category in scores2["c normalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores2["c normalized"][category], performance["c"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores2["c normalized"][category], performance["c"]["svm precision"])) 
    + "\n")
  o.write("k = 3" + "\n")
  for category in scores3["c normalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores3["c normalized"][category], performance["c"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores3["c normalized"][category], performance["c"]["svm precision"])) 
    + "\n")
  o.write("k = 4" + "\n")
  for category in scores4["c normalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores4["c normalized"][category], performance["c"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores4["c normalized"][category], performance["c"]["svm precision"])) 
    + "\n")
  o.write("C on D" + "\n")
  o.write("k = 2" + "\n")
  for category in scores2["c normalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores2["c normalized"][category], performance["d"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores2["c normalized"][category], performance["d"]["svm precision"])) 
    + "\n")
  o.write("k = 3" + "\n")
  for category in scores3["c normalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores3["c normalized"][category], performance["d"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores3["c normalized"][category], performance["d"]["svm precision"])) 
    + "\n")
  o.write("k = 4" + "\n")
  for category in scores4["c normalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores4["c normalized"][category], performance["d"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores4["c normalized"][category], performance["d"]["svm precision"])) 
    + "\n")
  # D
  o.write("D on B" + "\n")
  o.write("k = 2" + "\n")
  for category in scores2["d normalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores2["d normalized"][category], performance["b"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores2["d normalized"][category], performance["b"]["svm precision"])) 
    + "\n")
  o.write("k = 3" + "\n")
  for category in scores3["d normalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores3["d normalized"][category], performance["b"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores3["d normalized"][category], performance["b"]["svm precision"])) 
    + "\n")
  o.write("k = 4" + "\n")
  for category in scores4["d normalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores4["d normalized"][category], performance["b"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores4["d normalized"][category], performance["b"]["svm precision"])) 
    + "\n")
  o.write("D on C" + "\n")
  o.write("k = 2" + "\n")
  for category in scores2["d normalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores2["d normalized"][category], performance["c"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores2["d normalized"][category], performance["c"]["svm precision"])) 
    + "\n")
  o.write("k = 3" + "\n")
  for category in scores3["d normalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores3["d normalized"][category], performance["c"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores3["d normalized"][category], performance["c"]["svm precision"])) 
    + "\n")
  o.write("k = 4" + "\n")
  for category in scores4["d normalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores4["d normalized"][category], performance["c"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores4["d normalized"][category], performance["c"]["svm precision"])) 
    + "\n")
  o.write("D on D" + "\n")
  o.write("k = 2" + "\n")
  for category in scores2["d normalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores2["d normalized"][category], performance["d"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores2["d normalized"][category], performance["d"]["svm precision"])) 
    + "\n")
  o.write("k = 3" + "\n")
  for category in scores3["d normalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores3["d normalized"][category], performance["d"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores3["d normalized"][category], performance["d"]["svm precision"])) 
    + "\n")
  o.write("k = 4" + "\n")
  for category in scores4["d normalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores4["d normalized"][category], performance["d"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores4["d normalized"][category], performance["d"]["svm precision"])) 
    + "\n")

# %%
# muse, 30 trials
from scipy import stats
import csv
scores2 = {"b normalized": {}, "c normalized": {}, "d normalized": {},
          "b unnormalized": {}, "c unnormalized": {}, "d unnormalized": {}}
scores3 = {"b normalized": {}, "c normalized": {}, "d normalized": {},
          "b unnormalized": {}, "c unnormalized": {}, "d unnormalized": {}}
scores4 = {"b normalized": {}, "c normalized": {}, "d normalized": {},
          "b unnormalized": {}, "c unnormalized": {}, "d unnormalized": {}}
conversion = {"du": "d unnormalized", "dn": "d normalized",
              "cu": "c unnormalized", "cn": "c normalized",
              "bu": "b unnormalized", "bn": "b normalized"}
for k in conversion.keys():
  with open(k + "2.csv", newline="") as csvfile:
    reader = csv.reader(csvfile)
    rows = [row for row in reader]
    for i in range(len(rows[0][1:])):
      scores2[conversion[k]][rows[0][i + 1]] = [float(score[i + 1]) for score in rows[1:]]
for k in conversion.keys():
  with open(k + "3.csv", newline="") as csvfile:
    reader = csv.reader(csvfile)
    rows = [row for row in reader]
    for i in range(len(rows[0][1:])):
      scores3[conversion[k]][rows[0][i + 1]] = [float(score[i + 1]) for score in rows[1:]]
for k in conversion.keys():
  with open(k + "4.csv", newline="") as csvfile:
    reader = csv.reader(csvfile)
    rows = [row for row in reader]
    for i in range(len(rows[0][1:])):
      scores4[conversion[k]][rows[0][i + 1]] = [float(score[i + 1]) for score in rows[1:]]
performance = {"b": {"svm accuracy": [0.7394343434, 0.7434713805, 0.8189191919, 0.7187373737,
0.7440639731, 0.7337407407, 0.8175791246, 0.87103367, 0.7527845118, 0.7397710438, 0.8258989899,
0.7417811448, 0.5820942761, 0.7848484848, 0.8182828283, 0.7988821549, 0.7136734007, 0.7544478114,
0.7591144781, 0.8192929293, 0.7230572391, 0.7741582492, 0.695010101, 0.7494781145, 0.8667138047,
0.7207441077, 0.8015656566, 0.7434276094, 0.7224276094],
            "svm precision": [0.5147425425, 0.5474948429, 0.6402944964, 0.5126869184, 0.5613977843,
0.537132228, 0.62617972, 0.697997719, 0.5817829722, 0.6274076805, 0.6394641556, 0.5250325671,
0.3951158418, 0.6434601865, 0.5809606837, 0.6377273618, 0.6015585221, 0.5759866704, 0.5839562862,
0.6504294501, 0.5605764817, 0.5606690411, 0.5094513485, 0.6258969468, 0.7171399857, 0.5373588033,
0.5863675111, 0.5576247718, 0.4906650285]}, 
      "c": {"svm accuracy": [0.9115117845, 0.9008619529, 0.9272424242, 0.9131885522, 0.9172289562,
0.9148888889, 0.9365757576, 0.9486026936, 0.9132188552, 0.9075117845, 0.9258888889, 0.9105454545,
0.8227306397, 0.9385757576, 0.9339090909, 0.9259057239, 0.9222356902, 0.9088619529, 0.9155286195,
0.9315757576, 0.8955252525, 0.9232222222, 0.8908383838, 0.8951986532, 0.9436060606, 0.8982053872,
0.9145286195, 0.9262289562, 0.8818047138],
            "svm precision": [0.897825603, 0.8713204013, 0.9256472319, 0.9146828206, 0.9009023001,
0.9087182426, 0.931490078, 0.9516104885, 0.9025356258, 0.8939500887, 0.9160238603, 0.8975107206,
0.7177907782, 0.9337669811, 0.9150639428, 0.9147005825, 0.9281775487, 0.9039012088, 0.9332942971,
0.9190953523, 0.8724923911, 0.9200006485, 0.8713990654, 0.8796500718, 0.9546340743, 0.8940336208,
0.9047014374, 0.9529267728, 0.8363634304]}, 
      "d": {"svm accuracy": [0.4828181818, 0.5272424242, 0.6167407407, 0.4851885522, 0.5028821549,
0.5526228956, 0.6300808081, 0.6791515152, 0.4998585859, 0.5161986532, 0.6290774411, 0.5202390572,
0.2176902357, 0.5662962963, 0.6351043771, 0.5826700337, 0.5058518519, 0.538962963, 0.5025454545,
0.6023434343, 0.4534309764, 0.5208922559, 0.4484276094, 0.4731717172, 0.6561279461, 0.4911784512,
0.5662996633, 0.4848215488, 0.5161717172],
            "svm precision": [0.3967611835, 0.406490262, 0.5356452402, 0.4312518178, 0.4448020409,
0.4154506511, 0.5193483822, 0.5367970787, 0.4241632703, 0.4538746826, 0.4910612437, 0.4349008885,
0.2387549638, 0.4877843385, 0.515831218, 0.4784900631, 0.4320133245, 0.4402419238, 0.4290912667,
0.486993653, 0.3792931449, 0.4688426068, 0.3822483611, 0.4366582397, 0.5535475846, 0.4200121244,
0.4815876177, 0.4484124253, 0.4192702599]}}
with open("unnormalizedmuse30.txt", "w") as o:
  o.write("B on B" + "\n")
  o.write("k = 2" + "\n")
  for category in scores2["b unnormalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores2["b unnormalized"][category], performance["b"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores2["b unnormalized"][category], performance["b"]["svm precision"])) 
    + "\n")
  o.write("k = 3" + "\n")
  for category in scores3["b unnormalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores3["b unnormalized"][category], performance["b"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores3["b unnormalized"][category], performance["b"]["svm precision"])) 
    + "\n")
  o.write("k = 4" + "\n")
  for category in scores4["b unnormalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores4["b unnormalized"][category], performance["b"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores4["b unnormalized"][category], performance["b"]["svm precision"])) 
    + "\n")
  o.write("B on C" + "\n")
  o.write("k = 2" + "\n")
  for category in scores2["b unnormalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores2["b unnormalized"][category], performance["c"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores2["b unnormalized"][category], performance["c"]["svm precision"])) 
    + "\n")
  o.write("k = 3" + "\n")
  for category in scores3["b unnormalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores3["b unnormalized"][category], performance["c"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores3["b unnormalized"][category], performance["c"]["svm precision"])) 
    + "\n")
  o.write("k = 4" + "\n")
  for category in scores4["b unnormalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores4["b unnormalized"][category], performance["c"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores4["b unnormalized"][category], performance["c"]["svm precision"])) 
    + "\n")
  o.write("B on D" + "\n")
  o.write("k = 2" + "\n")
  for category in scores2["b unnormalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores2["b unnormalized"][category], performance["d"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores2["b unnormalized"][category], performance["d"]["svm precision"]))
    + "\n") 
  o.write("k = 3" + "\n")
  for category in scores3["b unnormalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores3["b unnormalized"][category], performance["d"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores3["b unnormalized"][category], performance["d"]["svm precision"])) 
    + "\n")
  o.write("k = 4" + "\n")
  for category in scores4["b unnormalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores4["b unnormalized"][category], performance["d"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores4["b unnormalized"][category], performance["d"]["svm precision"])) 
    + "\n")
  # C
  o.write("C on B" + "\n")
  o.write("k = 2" + "\n")
  for category in scores2["c unnormalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores2["c unnormalized"][category], performance["b"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores2["c unnormalized"][category], performance["b"]["svm precision"])) 
    + "\n")
  o.write("k = 3" + "\n")
  for category in scores3["c unnormalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores3["c unnormalized"][category], performance["b"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores3["c unnormalized"][category], performance["b"]["svm precision"])) 
    + "\n")
  o.write("k = 4" + "\n")
  for category in scores4["c unnormalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores4["c unnormalized"][category], performance["b"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores4["c unnormalized"][category], performance["b"]["svm precision"])) 
    + "\n")
  o.write("C on C" + "\n")
  o.write("k = 2" + "\n")
  for category in scores2["c unnormalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores2["c unnormalized"][category], performance["c"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores2["c unnormalized"][category], performance["c"]["svm precision"])) 
    + "\n")
  o.write("k = 3" + "\n")
  for category in scores3["c unnormalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores3["c unnormalized"][category], performance["c"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores3["c unnormalized"][category], performance["c"]["svm precision"])) 
    + "\n")
  o.write("k = 4" + "\n")
  for category in scores4["c unnormalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores4["c unnormalized"][category], performance["c"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores4["c unnormalized"][category], performance["c"]["svm precision"])) 
    + "\n")
  o.write("C on D" + "\n")
  o.write("k = 2" + "\n")
  for category in scores2["c unnormalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores2["c unnormalized"][category], performance["d"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores2["c unnormalized"][category], performance["d"]["svm precision"])) 
    + "\n")
  o.write("k = 3" + "\n")
  for category in scores3["c unnormalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores3["c unnormalized"][category], performance["d"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores3["c unnormalized"][category], performance["d"]["svm precision"])) 
    + "\n")
  o.write("k = 4" + "\n")
  for category in scores4["c unnormalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores4["c unnormalized"][category], performance["d"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores4["c unnormalized"][category], performance["d"]["svm precision"])) 
    + "\n")
  # D
  o.write("D on B" + "\n")
  o.write("k = 2" + "\n")
  for category in scores2["d unnormalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores2["d unnormalized"][category], performance["b"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores2["d unnormalized"][category], performance["b"]["svm precision"])) 
    + "\n")
  o.write("k = 3" + "\n")
  for category in scores3["d unnormalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores3["d unnormalized"][category], performance["b"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores3["d unnormalized"][category], performance["b"]["svm precision"])) 
    + "\n")
  o.write("k = 4" + "\n")
  for category in scores4["d unnormalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores4["d unnormalized"][category], performance["b"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores4["d unnormalized"][category], performance["b"]["svm precision"])) 
    + "\n")
  o.write("D on C" + "\n")
  o.write("k = 2" + "\n")
  for category in scores2["d unnormalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores2["d unnormalized"][category], performance["c"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores2["d unnormalized"][category], performance["c"]["svm precision"])) 
    + "\n")
  o.write("k = 3" + "\n")
  for category in scores3["d unnormalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores3["d unnormalized"][category], performance["c"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores3["d unnormalized"][category], performance["c"]["svm precision"])) 
    + "\n")
  o.write("k = 4" + "\n")
  for category in scores4["d unnormalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores4["d unnormalized"][category], performance["c"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores4["d unnormalized"][category], performance["c"]["svm precision"])) 
    + "\n")
  o.write("D on D" + "\n")
  o.write("k = 2" + "\n")
  for category in scores2["d unnormalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores2["d unnormalized"][category], performance["d"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores2["d unnormalized"][category], performance["d"]["svm precision"])) 
    + "\n")
  o.write("k = 3" + "\n")
  for category in scores3["d unnormalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores3["d unnormalized"][category], performance["d"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores3["d unnormalized"][category], performance["d"]["svm precision"])) 
    + "\n")
  o.write("k = 4" + "\n")
  for category in scores4["d unnormalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores4["d unnormalized"][category], performance["d"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores4["d unnormalized"][category], performance["d"]["svm precision"])) 
    + "\n")


with open("normalizedmuse30.txt", "w") as o:
  o.write("B on B" + "\n")
  o.write("k = 2" + "\n")
  for category in scores2["b normalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores2["b normalized"][category], performance["b"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores2["b normalized"][category], performance["b"]["svm precision"])) 
    + "\n")
  o.write("k = 3" + "\n")
  for category in scores3["b normalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores3["b normalized"][category], performance["b"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores3["b normalized"][category], performance["b"]["svm precision"])) 
    + "\n")
  o.write("k = 4" + "\n")
  for category in scores4["b normalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores4["b normalized"][category], performance["b"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores4["b normalized"][category], performance["b"]["svm precision"])) 
    + "\n")
  o.write("B on C" + "\n")
  o.write("k = 2" + "\n")
  for category in scores2["b normalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores2["b normalized"][category], performance["c"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores2["b normalized"][category], performance["c"]["svm precision"])) 
    + "\n")
  o.write("k = 3" + "\n")
  for category in scores3["b normalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores3["b normalized"][category], performance["c"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores3["b normalized"][category], performance["c"]["svm precision"])) 
    + "\n")
  o.write("k = 4" + "\n")
  for category in scores4["b normalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores4["b normalized"][category], performance["c"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores4["b normalized"][category], performance["c"]["svm precision"])) 
    + "\n")
  o.write("B on D" + "\n")
  o.write("k = 2" + "\n")
  for category in scores2["b normalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores2["b normalized"][category], performance["d"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores2["b normalized"][category], performance["d"]["svm precision"])) 
    + "\n")
  o.write("k = 3" + "\n")
  for category in scores3["b normalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores3["b normalized"][category], performance["d"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores3["b normalized"][category], performance["d"]["svm precision"])) 
    + "\n")
  o.write("k = 4" + "\n")
  for category in scores4["b normalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores4["b normalized"][category], performance["d"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores4["b normalized"][category], performance["d"]["svm precision"])) 
    + "\n")
  # C
  o.write("C on B" + "\n")
  o.write("k = 2" + "\n")
  for category in scores2["c normalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores2["c normalized"][category], performance["b"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores2["c normalized"][category], performance["b"]["svm precision"])) 
    + "\n")
  o.write("k = 3" + "\n")
  for category in scores3["c normalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores3["c normalized"][category], performance["b"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores3["c normalized"][category], performance["b"]["svm precision"])) 
    + "\n")
  o.write("k = 4" + "\n")
  for category in scores4["c normalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores4["c normalized"][category], performance["b"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores4["c normalized"][category], performance["b"]["svm precision"])) 
    + "\n")
  o.write("C on C" + "\n")
  o.write("k = 2" + "\n")
  for category in scores2["c normalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores2["c normalized"][category], performance["c"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores2["c normalized"][category], performance["c"]["svm precision"])) 
    + "\n")
  o.write("k = 3" + "\n")
  for category in scores3["c normalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores3["c normalized"][category], performance["c"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores3["c normalized"][category], performance["c"]["svm precision"])) 
    + "\n")
  o.write("k = 4" + "\n")
  for category in scores4["c normalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores4["c normalized"][category], performance["c"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores4["c normalized"][category], performance["c"]["svm precision"])) 
    + "\n")
  o.write("C on D" + "\n")
  o.write("k = 2" + "\n")
  for category in scores2["c normalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores2["c normalized"][category], performance["d"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores2["c normalized"][category], performance["d"]["svm precision"])) 
    + "\n")
  o.write("k = 3" + "\n")
  for category in scores3["c normalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores3["c normalized"][category], performance["d"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores3["c normalized"][category], performance["d"]["svm precision"])) 
    + "\n")
  o.write("k = 4" + "\n")
  for category in scores4["c normalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores4["c normalized"][category], performance["d"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores4["c normalized"][category], performance["d"]["svm precision"])) 
    + "\n")
  # D
  o.write("D on B" + "\n")
  o.write("k = 2" + "\n")
  for category in scores2["d normalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores2["d normalized"][category], performance["b"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores2["d normalized"][category], performance["b"]["svm precision"])) 
    + "\n")
  o.write("k = 3" + "\n")
  for category in scores3["d normalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores3["d normalized"][category], performance["b"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores3["d normalized"][category], performance["b"]["svm precision"])) 
    + "\n")
  o.write("k = 4" + "\n")
  for category in scores4["d normalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores4["d normalized"][category], performance["b"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores4["d normalized"][category], performance["b"]["svm precision"])) 
    + "\n")
  o.write("D on C" + "\n")
  o.write("k = 2" + "\n")
  for category in scores2["d normalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores2["d normalized"][category], performance["c"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores2["d normalized"][category], performance["c"]["svm precision"])) 
    + "\n")
  o.write("k = 3" + "\n")
  for category in scores3["d normalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores3["d normalized"][category], performance["c"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores3["d normalized"][category], performance["c"]["svm precision"])) 
    + "\n")
  o.write("k = 4" + "\n")
  for category in scores4["d normalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores4["d normalized"][category], performance["c"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores4["d normalized"][category], performance["c"]["svm precision"])) 
    + "\n")
  o.write("D on D" + "\n")
  o.write("k = 2" + "\n")
  for category in scores2["d normalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores2["d normalized"][category], performance["d"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores2["d normalized"][category], performance["d"]["svm precision"])) 
    + "\n")
  o.write("k = 3" + "\n")
  for category in scores3["d normalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores3["d normalized"][category], performance["d"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores3["d normalized"][category], performance["d"]["svm precision"])) 
    + "\n")
  o.write("k = 4" + "\n")
  for category in scores4["d normalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores4["d normalized"][category], performance["d"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores4["d normalized"][category], performance["d"]["svm precision"])) 
    + "\n")

# %%
len([0.016364, 0.007824000000000001, 0.042276, 0.003176, 0.013864000000000001, 0.006016, 0.003304, 0.003244, 0.013296, 0.006844, 0.012204, 0.023084, 0.007056000000000001, 0.0046, 0.012136, 0.003304, 0.004176, 0.000464, 0.020724, 0.004516, 0.0109, 0.007204, 0.0040999999999999995, 0.003676, 0.005016, 0.0066, 0.0046760000000000005, 0.002856, 0.001936, 0.012324, 0.014796000000000002])
# Out:
# 31

# %%
len([0.022520298671486468, 0.011147185241589754, 0.04944898625185135, 0.00454227227972699, 0.017639134109299036, 0.007164154958844809, 0.004676155650575559, 0.004613397820490292, 0.01111789825421663, 0.009947813377737983, 0.01607716144939906, 0.026236956830980613, 0.008949266570159072, 0.005857397474624917, 0.018097963578144655, 0.003978846427405926, 0.005936890726066256, 0.0006596545251184728, 0.029521283272109587, 0.006466845735675177, 0.012969951550955174, 0.010498687664041995, 0.005857397474624917, 0.005239581502896623, 0.006466845735675177, 0.009518270896265491, 0.005936890726066256, 0.004033236546813157, 0.002722295207254247, 0.01533104058060755, 0.020880227378591496])
# Out:
# 31

# %%
# subs2vec, 1 trial
from scipy import stats
import csv
scores2 = {"b normalized": {}, "c normalized": {}, "d normalized": {},
          "b unnormalized": {}, "c unnormalized": {}, "d unnormalized": {}}
scores3 = {"b normalized": {}, "c normalized": {}, "d normalized": {},
          "b unnormalized": {}, "c unnormalized": {}, "d unnormalized": {}}
scores4 = {"b normalized": {}, "c normalized": {}, "d normalized": {},
          "b unnormalized": {}, "c unnormalized": {}, "d unnormalized": {}}
conversion = {"du": "d unnormalized", "dn": "d normalized",
              "cu": "c unnormalized", "cn": "c normalized",
              "bu": "b unnormalized", "bn": "b normalized"}
for k in conversion.keys():
  with open(k + "2.csv", newline="") as csvfile:
    reader = csv.reader(csvfile)
    rows = [row for row in reader]
    for i in range(len(rows[0][1:])):
      scores2[conversion[k]][rows[0][i + 1]] = [float(score[i + 1]) for score in rows[1:]]
for k in conversion.keys():
  with open(k + "3.csv", newline="") as csvfile:
    reader = csv.reader(csvfile)
    rows = [row for row in reader]
    for i in range(len(rows[0][1:])):
      scores3[conversion[k]][rows[0][i + 1]] = [float(score[i + 1]) for score in rows[1:]]
for k in conversion.keys():
  with open(k + "4.csv", newline="") as csvfile:
    reader = csv.reader(csvfile)
    rows = [row for row in reader]
    for i in range(len(rows[0][1:])):
      scores4[conversion[k]][rows[0][i + 1]] = [float(score[i + 1]) for score in rows[1:]]
performance = {"b": {"svm accuracy": [0.53, 0.86, 0.6, 0.83, 0.81, 0.74, 0.86, 0.91, 0.73, 0.59,
0.85, 0.57, 0.38, 0.86, 0.84, 0.8, 0.71, 0.78, 0.89, 0.88, 0.8, 0.56, 0.74, 0.84, 0.71, 0.79, 0.86,
0.67, 0.63],
            "svm precision": [0.1712147887, 0.6208126432, 0.428395179, 0.6039231602, 0.5657427678,
0.4839285714, 0.7454879679, 0.6365079365, 0.4726540616, 0.4168315018, 0.5544665235, 0.2104166667,
0.1793154762, 0.5856456044, 0.6732142857, 0.5433454106, 0.5183725005, 0.5572170104, 0.6314162811,
0.7398196779, 0.5786324786, 0.2883493031, 0.4292598344, 0.6044973545, 0.3902803494, 0.542742674,
0.5898122711, 0.4562287415, 0.4179743867]}, 
      "c": {"svm accuracy": [0.84, 0.97, 0.83, 0.92, 0.95, 0.92, 0.95, 0.96, 0.85, 0.82, 0.95, 0.85,
0.76, 0.96, 0.92, 0.9, 0.78, 0.93, 0.94, 0.94, 0.95, 0.83, 0.95, 0.94, 0.84, 0.93, 0.98, 0.8, 0.88],
            "svm precision": [0.7818740399, 0.9600271003, 0.7234848485, 0.8700454841, 0.9449404762,
0.8980392157, 0.9125, 0.9222423146, 0.7587719298, 0.7008547009, 0.9026806527, 0.7833333333,
0.5676392573, 0.9222423146, 0.8565782044, 0.8283455675, 0.6426250812, 0.8922764228, 0.9025341131,
0.8921036769, 0.9125, 0.7916666667, 0.9261517615, 0.8848108413, 0.7411764706, 0.9077380952,
0.9523809524, 0.6751137102, 0.8050682261]}, 
      "d": {"svm accuracy": [0.19, 0.69, 0.27, 0.61, 0.71, 0.63, 0.74, 0.77, 0.5, 0.3, 0.72, 0.36,
0.17, 0.71, 0.63, 0.69, 0.43, 0.52, 0.7, 0.71, 0.64, 0.22, 0.5, 0.63, 0.32, 0.7, 0.67, 0.22, 0.44],
            "svm precision": [0.1082173825, 0.6469444444, 0.2478774929, 0.5229885057, 0.6004291685,
0.5454980843, 0.6940512266, 0.7171592775, 0.4125661376, 0.2897214854, 0.6712643678, 0.3002663046,
0.09778325123, 0.5956486043, 0.5175175399, 0.6548440066, 0.3844827586, 0.4186445738, 0.6411772487,
0.5910509031, 0.5943518519, 0.1537037037, 0.4288888889, 0.5215367965, 0.2235109718, 0.630952381,
0.5114121511, 0.1848522167, 0.3806940186]}}
with open("unnormalizedsubs1.txt", "w") as o:
  o.write("B on B" + "\n")
  o.write("k = 2" + "\n")
  for category in scores2["b unnormalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores2["b unnormalized"][category], performance["b"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores2["b unnormalized"][category], performance["b"]["svm precision"])) 
    + "\n")
  o.write("k = 3" + "\n")
  for category in scores3["b unnormalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores3["b unnormalized"][category], performance["b"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores3["b unnormalized"][category], performance["b"]["svm precision"])) 
    + "\n")
  o.write("k = 4" + "\n")
  for category in scores4["b unnormalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores4["b unnormalized"][category], performance["b"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores4["b unnormalized"][category], performance["b"]["svm precision"])) 
    + "\n")
  o.write("B on C" + "\n")
  o.write("k = 2" + "\n")
  for category in scores2["b unnormalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores2["b unnormalized"][category], performance["c"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores2["b unnormalized"][category], performance["c"]["svm precision"])) 
    + "\n")
  o.write("k = 3" + "\n")
  for category in scores3["b unnormalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores3["b unnormalized"][category], performance["c"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores3["b unnormalized"][category], performance["c"]["svm precision"])) 
    + "\n")
  o.write("k = 4" + "\n")
  for category in scores4["b unnormalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores4["b unnormalized"][category], performance["c"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores4["b unnormalized"][category], performance["c"]["svm precision"])) 
    + "\n")
  o.write("B on D" + "\n")
  o.write("k = 2" + "\n")
  for category in scores2["b unnormalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores2["b unnormalized"][category], performance["d"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores2["b unnormalized"][category], performance["d"]["svm precision"]))
    + "\n") 
  o.write("k = 3" + "\n")
  for category in scores3["b unnormalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores3["b unnormalized"][category], performance["d"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores3["b unnormalized"][category], performance["d"]["svm precision"])) 
    + "\n")
  o.write("k = 4" + "\n")
  for category in scores4["b unnormalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores4["b unnormalized"][category], performance["d"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores4["b unnormalized"][category], performance["d"]["svm precision"])) 
    + "\n")
  # C
  o.write("C on B" + "\n")
  o.write("k = 2" + "\n")
  for category in scores2["c unnormalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores2["c unnormalized"][category], performance["b"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores2["c unnormalized"][category], performance["b"]["svm precision"])) 
    + "\n")
  o.write("k = 3" + "\n")
  for category in scores3["c unnormalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores3["c unnormalized"][category], performance["b"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores3["c unnormalized"][category], performance["b"]["svm precision"])) 
    + "\n")
  o.write("k = 4" + "\n")
  for category in scores4["c unnormalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores4["c unnormalized"][category], performance["b"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores4["c unnormalized"][category], performance["b"]["svm precision"])) 
    + "\n")
  o.write("C on C" + "\n")
  o.write("k = 2" + "\n")
  for category in scores2["c unnormalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores2["c unnormalized"][category], performance["c"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores2["c unnormalized"][category], performance["c"]["svm precision"])) 
    + "\n")
  o.write("k = 3" + "\n")
  for category in scores3["c unnormalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores3["c unnormalized"][category], performance["c"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores3["c unnormalized"][category], performance["c"]["svm precision"])) 
    + "\n")
  o.write("k = 4" + "\n")
  for category in scores4["c unnormalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores4["c unnormalized"][category], performance["c"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores4["c unnormalized"][category], performance["c"]["svm precision"])) 
    + "\n")
  o.write("C on D" + "\n")
  o.write("k = 2" + "\n")
  for category in scores2["c unnormalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores2["c unnormalized"][category], performance["d"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores2["c unnormalized"][category], performance["d"]["svm precision"])) 
    + "\n")
  o.write("k = 3" + "\n")
  for category in scores3["c unnormalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores3["c unnormalized"][category], performance["d"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores3["c unnormalized"][category], performance["d"]["svm precision"])) 
    + "\n")
  o.write("k = 4" + "\n")
  for category in scores4["c unnormalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores4["c unnormalized"][category], performance["d"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores4["c unnormalized"][category], performance["d"]["svm precision"])) 
    + "\n")
  # D
  o.write("D on B" + "\n")
  o.write("k = 2" + "\n")
  for category in scores2["d unnormalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores2["d unnormalized"][category], performance["b"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores2["d unnormalized"][category], performance["b"]["svm precision"])) 
    + "\n")
  o.write("k = 3" + "\n")
  for category in scores3["d unnormalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores3["d unnormalized"][category], performance["b"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores3["d unnormalized"][category], performance["b"]["svm precision"])) 
    + "\n")
  o.write("k = 4" + "\n")
  for category in scores4["d unnormalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores4["d unnormalized"][category], performance["b"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores4["d unnormalized"][category], performance["b"]["svm precision"])) 
    + "\n")
  o.write("D on C" + "\n")
  o.write("k = 2" + "\n")
  for category in scores2["d unnormalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores2["d unnormalized"][category], performance["c"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores2["d unnormalized"][category], performance["c"]["svm precision"])) 
    + "\n")
  o.write("k = 3" + "\n")
  for category in scores3["d unnormalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores3["d unnormalized"][category], performance["c"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores3["d unnormalized"][category], performance["c"]["svm precision"])) 
    + "\n")
  o.write("k = 4" + "\n")
  for category in scores4["d unnormalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores4["d unnormalized"][category], performance["c"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores4["d unnormalized"][category], performance["c"]["svm precision"])) 
    + "\n")
  o.write("D on D" + "\n")
  o.write("k = 2" + "\n")
  for category in scores2["d unnormalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores2["d unnormalized"][category], performance["d"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores2["d unnormalized"][category], performance["d"]["svm precision"])) 
    + "\n")
  o.write("k = 3" + "\n")
  for category in scores3["d unnormalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores3["d unnormalized"][category], performance["d"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores3["d unnormalized"][category], performance["d"]["svm precision"])) 
    + "\n")
  o.write("k = 4" + "\n")
  for category in scores4["d unnormalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores4["d unnormalized"][category], performance["d"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores4["d unnormalized"][category], performance["d"]["svm precision"])) 
    + "\n")


with open("normalizedsubs1.txt", "w") as o:
  o.write("B on B" + "\n")
  o.write("k = 2" + "\n")
  for category in scores2["b normalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores2["b normalized"][category], performance["b"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores2["b normalized"][category], performance["b"]["svm precision"])) 
    + "\n")
  o.write("k = 3" + "\n")
  for category in scores3["b normalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores3["b normalized"][category], performance["b"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores3["b normalized"][category], performance["b"]["svm precision"])) 
    + "\n")
  o.write("k = 4" + "\n")
  for category in scores4["b normalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores4["b normalized"][category], performance["b"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores4["b normalized"][category], performance["b"]["svm precision"])) 
    + "\n")
  o.write("B on C" + "\n")
  o.write("k = 2" + "\n")
  for category in scores2["b normalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores2["b normalized"][category], performance["c"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores2["b normalized"][category], performance["c"]["svm precision"])) 
    + "\n")
  o.write("k = 3" + "\n")
  for category in scores3["b normalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores3["b normalized"][category], performance["c"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores3["b normalized"][category], performance["c"]["svm precision"])) 
    + "\n")
  o.write("k = 4" + "\n")
  for category in scores4["b normalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores4["b normalized"][category], performance["c"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores4["b normalized"][category], performance["c"]["svm precision"])) 
    + "\n")
  o.write("B on D" + "\n")
  o.write("k = 2" + "\n")
  for category in scores2["b normalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores2["b normalized"][category], performance["d"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores2["b normalized"][category], performance["d"]["svm precision"])) 
    + "\n")
  o.write("k = 3" + "\n")
  for category in scores3["b normalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores3["b normalized"][category], performance["d"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores3["b normalized"][category], performance["d"]["svm precision"])) 
    + "\n")
  o.write("k = 4" + "\n")
  for category in scores4["b normalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores4["b normalized"][category], performance["d"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores4["b normalized"][category], performance["d"]["svm precision"])) 
    + "\n")
  # C
  o.write("C on B" + "\n")
  o.write("k = 2" + "\n")
  for category in scores2["c normalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores2["c normalized"][category], performance["b"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores2["c normalized"][category], performance["b"]["svm precision"])) 
    + "\n")
  o.write("k = 3" + "\n")
  for category in scores3["c normalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores3["c normalized"][category], performance["b"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores3["c normalized"][category], performance["b"]["svm precision"])) 
    + "\n")
  o.write("k = 4" + "\n")
  for category in scores4["c normalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores4["c normalized"][category], performance["b"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores4["c normalized"][category], performance["b"]["svm precision"])) 
    + "\n")
  o.write("C on C" + "\n")
  o.write("k = 2" + "\n")
  for category in scores2["c normalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores2["c normalized"][category], performance["c"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores2["c normalized"][category], performance["c"]["svm precision"])) 
    + "\n")
  o.write("k = 3" + "\n")
  for category in scores3["c normalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores3["c normalized"][category], performance["c"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores3["c normalized"][category], performance["c"]["svm precision"])) 
    + "\n")
  o.write("k = 4" + "\n")
  for category in scores4["c normalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores4["c normalized"][category], performance["c"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores4["c normalized"][category], performance["c"]["svm precision"])) 
    + "\n")
  o.write("C on D" + "\n")
  o.write("k = 2" + "\n")
  for category in scores2["c normalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores2["c normalized"][category], performance["d"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores2["c normalized"][category], performance["d"]["svm precision"])) 
    + "\n")
  o.write("k = 3" + "\n")
  for category in scores3["c normalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores3["c normalized"][category], performance["d"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores3["c normalized"][category], performance["d"]["svm precision"])) 
    + "\n")
  o.write("k = 4" + "\n")
  for category in scores4["c normalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores4["c normalized"][category], performance["d"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores4["c normalized"][category], performance["d"]["svm precision"])) 
    + "\n")
  # D
  o.write("D on B" + "\n")
  o.write("k = 2" + "\n")
  for category in scores2["d normalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores2["d normalized"][category], performance["b"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores2["d normalized"][category], performance["b"]["svm precision"])) 
    + "\n")
  o.write("k = 3" + "\n")
  for category in scores3["d normalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores3["d normalized"][category], performance["b"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores3["d normalized"][category], performance["b"]["svm precision"])) 
    + "\n")
  o.write("k = 4" + "\n")
  for category in scores4["d normalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores4["d normalized"][category], performance["b"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores4["d normalized"][category], performance["b"]["svm precision"])) 
    + "\n")
  o.write("D on C" + "\n")
  o.write("k = 2" + "\n")
  for category in scores2["d normalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores2["d normalized"][category], performance["c"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores2["d normalized"][category], performance["c"]["svm precision"])) 
    + "\n")
  o.write("k = 3" + "\n")
  for category in scores3["d normalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores3["d normalized"][category], performance["c"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores3["d normalized"][category], performance["c"]["svm precision"])) 
    + "\n")
  o.write("k = 4" + "\n")
  for category in scores4["d normalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores4["d normalized"][category], performance["c"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores4["d normalized"][category], performance["c"]["svm precision"])) 
    + "\n")
  o.write("D on D" + "\n")
  o.write("k = 2" + "\n")
  for category in scores2["d normalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores2["d normalized"][category], performance["d"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores2["d normalized"][category], performance["d"]["svm precision"])) 
    + "\n")
  o.write("k = 3" + "\n")
  for category in scores3["d normalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores3["d normalized"][category], performance["d"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores3["d normalized"][category], performance["d"]["svm precision"])) 
    + "\n")
  o.write("k = 4" + "\n")
  for category in scores4["d normalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores4["d normalized"][category], performance["d"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores4["d normalized"][category], performance["d"]["svm precision"])) 
    + "\n")

# %%
# subs2vec, 30 trials
from scipy import stats
import csv
scores2 = {"b normalized": {}, "c normalized": {}, "d normalized": {},
          "b unnormalized": {}, "c unnormalized": {}, "d unnormalized": {}}
scores3 = {"b normalized": {}, "c normalized": {}, "d normalized": {},
          "b unnormalized": {}, "c unnormalized": {}, "d unnormalized": {}}
scores4 = {"b normalized": {}, "c normalized": {}, "d normalized": {},
          "b unnormalized": {}, "c unnormalized": {}, "d unnormalized": {}}
conversion = {"du": "d unnormalized", "dn": "d normalized",
              "cu": "c unnormalized", "cn": "c normalized",
              "bu": "b unnormalized", "bn": "b normalized"}
for k in conversion.keys():
  with open(k + "2.csv", newline="") as csvfile:
    reader = csv.reader(csvfile)
    rows = [row for row in reader]
    for i in range(len(rows[0][1:])):
      scores2[conversion[k]][rows[0][i + 1]] = [float(score[i + 1]) for score in rows[1:]]
for k in conversion.keys():
  with open(k + "3.csv", newline="") as csvfile:
    reader = csv.reader(csvfile)
    rows = [row for row in reader]
    for i in range(len(rows[0][1:])):
      scores3[conversion[k]][rows[0][i + 1]] = [float(score[i + 1]) for score in rows[1:]]
for k in conversion.keys():
  with open(k + "4.csv", newline="") as csvfile:
    reader = csv.reader(csvfile)
    rows = [row for row in reader]
    for i in range(len(rows[0][1:])):
      scores4[conversion[k]][rows[0][i + 1]] = [float(score[i + 1]) for score in rows[1:]]
performance = {"b": {"svm accuracy": [0.5482929293, 0.8398451178, 0.6389427609, 0.8381548822,
0.8234242424, 0.7829427609, 0.900037037, 0.9056632997, 0.7254680135, 0.6000740741, 0.8608720539,
0.563979798, 0.4185319865, 0.8725757576, 0.8173939394, 0.8331481481, 0.7445959596, 0.788959596,
0.8722558923, 0.8729292929, 0.7943434343, 0.5573569024, 0.7863164983, 0.8605690236, 0.6586228956,
0.8217340067, 0.883969697, 0.6476262626, 0.6923804714],
            "svm precision": [0.3292417684, 0.622055043, 0.4210915687, 0.6455527631, 0.6488459412,
0.5935201586, 0.7193452882, 0.7440730631, 0.4924639685, 0.4015354397, 0.6482095003, 0.2524556341,
0.194138624, 0.7034911759, 0.6196898253, 0.7120516625, 0.5836523684, 0.5989398641, 0.6933248633,
0.722120457, 0.6147424574, 0.2868046426, 0.5904331695, 0.7423450081, 0.4632996523, 0.6564408253,
0.6789269745, 0.4737179017, 0.459611614]}, 
      "c": {"svm accuracy": [0.8050673401, 0.9389124579, 0.8140909091, 0.9095521886, 0.9312188552,
0.9171986532, 0.9545993266, 0.9489393939, 0.8527676768, 0.8217205387, 0.9429090909, 0.8184107744,
0.741969697, 0.9385892256, 0.9429360269, 0.9185723906, 0.8617946128, 0.9108585859, 0.9465925926,
0.9238989899, 0.9215454545, 0.8253973064, 0.8944882155, 0.9328989899, 0.8377912458, 0.9405824916,
0.9419124579, 0.7816565657, 0.8247171717],
            "svm precision": [0.666078723, 0.9102840941, 0.6978404053, 0.857304944, 0.8995878671,
0.8809442121, 0.9423061378, 0.9262121274, 0.7635568678, 0.71222342, 0.9211439142, 0.6972174913,
0.5587052028, 0.9070074558, 0.9291739034, 0.8749253392, 0.7801795394, 0.8748836668, 0.9351163172,
0.884024839, 0.8779159133, 0.7312576134, 0.8424026595, 0.9127701691, 0.7423317596, 0.9223403348,
0.9173951196, 0.6524950366, 0.7201602564]}, 
      "d": {"svm accuracy": [0.1837845118, 0.6754444444, 0.2978754209, 0.6417575758, 0.6667777778,
0.6094040404, 0.7431582492, 0.7538316498, 0.4763164983, 0.2915286195, 0.7027845118, 0.3005319865,
0.1417508418, 0.7108181818, 0.6544175084, 0.6774410774, 0.4546262626, 0.575043771, 0.6921111111,
0.6904511785, 0.6274040404, 0.2471818182, 0.5396868687, 0.6337676768, 0.3905723906, 0.6561346801,
0.6921077441, 0.2618653199, 0.458969697],
            "svm precision": [0.1363619673, 0.5556054003, 0.251698478, 0.5160965612, 0.5587915054,
0.4991818515, 0.6434115208, 0.64327269, 0.3800034255, 0.2295970382, 0.6083757591, 0.2238165352,
0.1202849886, 0.5852762848, 0.5373341061, 0.5798170637, 0.3901647286, 0.4598649089, 0.5928973265,
0.6149538167, 0.5052153383, 0.1711280495, 0.4313569686, 0.5405750343, 0.2878409461, 0.5441337093,
0.5704337764, 0.2224415947, 0.3562775872]}}
with open("unnormalizedsubs30.txt", "w") as o:
  o.write("B on B" + "\n")
  o.write("k = 2" + "\n")
  for category in scores2["b unnormalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores2["b unnormalized"][category], performance["b"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores2["b unnormalized"][category], performance["b"]["svm precision"])) 
    + "\n")
  o.write("k = 3" + "\n")
  for category in scores3["b unnormalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores3["b unnormalized"][category], performance["b"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores3["b unnormalized"][category], performance["b"]["svm precision"])) 
    + "\n")
  o.write("k = 4" + "\n")
  for category in scores4["b unnormalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores4["b unnormalized"][category], performance["b"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores4["b unnormalized"][category], performance["b"]["svm precision"])) 
    + "\n")
  o.write("B on C" + "\n")
  o.write("k = 2" + "\n")
  for category in scores2["b unnormalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores2["b unnormalized"][category], performance["c"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores2["b unnormalized"][category], performance["c"]["svm precision"])) 
    + "\n")
  o.write("k = 3" + "\n")
  for category in scores3["b unnormalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores3["b unnormalized"][category], performance["c"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores3["b unnormalized"][category], performance["c"]["svm precision"])) 
    + "\n")
  o.write("k = 4" + "\n")
  for category in scores4["b unnormalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores4["b unnormalized"][category], performance["c"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores4["b unnormalized"][category], performance["c"]["svm precision"])) 
    + "\n")
  o.write("B on D" + "\n")
  o.write("k = 2" + "\n")
  for category in scores2["b unnormalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores2["b unnormalized"][category], performance["d"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores2["b unnormalized"][category], performance["d"]["svm precision"]))
    + "\n") 
  o.write("k = 3" + "\n")
  for category in scores3["b unnormalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores3["b unnormalized"][category], performance["d"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores3["b unnormalized"][category], performance["d"]["svm precision"])) 
    + "\n")
  o.write("k = 4" + "\n")
  for category in scores4["b unnormalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores4["b unnormalized"][category], performance["d"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores4["b unnormalized"][category], performance["d"]["svm precision"])) 
    + "\n")
  # C
  o.write("C on B" + "\n")
  o.write("k = 2" + "\n")
  for category in scores2["c unnormalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores2["c unnormalized"][category], performance["b"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores2["c unnormalized"][category], performance["b"]["svm precision"])) 
    + "\n")
  o.write("k = 3" + "\n")
  for category in scores3["c unnormalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores3["c unnormalized"][category], performance["b"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores3["c unnormalized"][category], performance["b"]["svm precision"])) 
    + "\n")
  o.write("k = 4" + "\n")
  for category in scores4["c unnormalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores4["c unnormalized"][category], performance["b"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores4["c unnormalized"][category], performance["b"]["svm precision"])) 
    + "\n")
  o.write("C on C" + "\n")
  o.write("k = 2" + "\n")
  for category in scores2["c unnormalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores2["c unnormalized"][category], performance["c"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores2["c unnormalized"][category], performance["c"]["svm precision"])) 
    + "\n")
  o.write("k = 3" + "\n")
  for category in scores3["c unnormalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores3["c unnormalized"][category], performance["c"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores3["c unnormalized"][category], performance["c"]["svm precision"])) 
    + "\n")
  o.write("k = 4" + "\n")
  for category in scores4["c unnormalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores4["c unnormalized"][category], performance["c"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores4["c unnormalized"][category], performance["c"]["svm precision"])) 
    + "\n")
  o.write("C on D" + "\n")
  o.write("k = 2" + "\n")
  for category in scores2["c unnormalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores2["c unnormalized"][category], performance["d"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores2["c unnormalized"][category], performance["d"]["svm precision"])) 
    + "\n")
  o.write("k = 3" + "\n")
  for category in scores3["c unnormalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores3["c unnormalized"][category], performance["d"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores3["c unnormalized"][category], performance["d"]["svm precision"])) 
    + "\n")
  o.write("k = 4" + "\n")
  for category in scores4["c unnormalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores4["c unnormalized"][category], performance["d"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores4["c unnormalized"][category], performance["d"]["svm precision"])) 
    + "\n")
  # D
  o.write("D on B" + "\n")
  o.write("k = 2" + "\n")
  for category in scores2["d unnormalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores2["d unnormalized"][category], performance["b"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores2["d unnormalized"][category], performance["b"]["svm precision"])) 
    + "\n")
  o.write("k = 3" + "\n")
  for category in scores3["d unnormalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores3["d unnormalized"][category], performance["b"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores3["d unnormalized"][category], performance["b"]["svm precision"])) 
    + "\n")
  o.write("k = 4" + "\n")
  for category in scores4["d unnormalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores4["d unnormalized"][category], performance["b"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores4["d unnormalized"][category], performance["b"]["svm precision"])) 
    + "\n")
  o.write("D on C" + "\n")
  o.write("k = 2" + "\n")
  for category in scores2["d unnormalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores2["d unnormalized"][category], performance["c"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores2["d unnormalized"][category], performance["c"]["svm precision"])) 
    + "\n")
  o.write("k = 3" + "\n")
  for category in scores3["d unnormalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores3["d unnormalized"][category], performance["c"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores3["d unnormalized"][category], performance["c"]["svm precision"])) 
    + "\n")
  o.write("k = 4" + "\n")
  for category in scores4["d unnormalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores4["d unnormalized"][category], performance["c"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores4["d unnormalized"][category], performance["c"]["svm precision"])) 
    + "\n")
  o.write("D on D" + "\n")
  o.write("k = 2" + "\n")
  for category in scores2["d unnormalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores2["d unnormalized"][category], performance["d"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores2["d unnormalized"][category], performance["d"]["svm precision"])) 
    + "\n")
  o.write("k = 3" + "\n")
  for category in scores3["d unnormalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores3["d unnormalized"][category], performance["d"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores3["d unnormalized"][category], performance["d"]["svm precision"])) 
    + "\n")
  o.write("k = 4" + "\n")
  for category in scores4["d unnormalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores4["d unnormalized"][category], performance["d"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores4["d unnormalized"][category], performance["d"]["svm precision"])) 
    + "\n")


with open("normalizedsubs30.txt", "w") as o:
  o.write("B on B" + "\n")
  o.write("k = 2" + "\n")
  for category in scores2["b normalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores2["b normalized"][category], performance["b"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores2["b normalized"][category], performance["b"]["svm precision"])) 
    + "\n")
  o.write("k = 3" + "\n")
  for category in scores3["b normalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores3["b normalized"][category], performance["b"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores3["b normalized"][category], performance["b"]["svm precision"])) 
    + "\n")
  o.write("k = 4" + "\n")
  for category in scores4["b normalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores4["b normalized"][category], performance["b"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores4["b normalized"][category], performance["b"]["svm precision"])) 
    + "\n")
  o.write("B on C" + "\n")
  o.write("k = 2" + "\n")
  for category in scores2["b normalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores2["b normalized"][category], performance["c"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores2["b normalized"][category], performance["c"]["svm precision"])) 
    + "\n")
  o.write("k = 3" + "\n")
  for category in scores3["b normalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores3["b normalized"][category], performance["c"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores3["b normalized"][category], performance["c"]["svm precision"])) 
    + "\n")
  o.write("k = 4" + "\n")
  for category in scores4["b normalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores4["b normalized"][category], performance["c"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores4["b normalized"][category], performance["c"]["svm precision"])) 
    + "\n")
  o.write("B on D" + "\n")
  o.write("k = 2" + "\n")
  for category in scores2["b normalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores2["b normalized"][category], performance["d"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores2["b normalized"][category], performance["d"]["svm precision"])) 
    + "\n")
  o.write("k = 3" + "\n")
  for category in scores3["b normalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores3["b normalized"][category], performance["d"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores3["b normalized"][category], performance["d"]["svm precision"])) 
    + "\n")
  o.write("k = 4" + "\n")
  for category in scores4["b normalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores4["b normalized"][category], performance["d"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores4["b normalized"][category], performance["d"]["svm precision"])) 
    + "\n")
  # C
  o.write("C on B" + "\n")
  o.write("k = 2" + "\n")
  for category in scores2["c normalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores2["c normalized"][category], performance["b"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores2["c normalized"][category], performance["b"]["svm precision"])) 
    + "\n")
  o.write("k = 3" + "\n")
  for category in scores3["c normalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores3["c normalized"][category], performance["b"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores3["c normalized"][category], performance["b"]["svm precision"])) 
    + "\n")
  o.write("k = 4" + "\n")
  for category in scores4["c normalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores4["c normalized"][category], performance["b"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores4["c normalized"][category], performance["b"]["svm precision"])) 
    + "\n")
  o.write("C on C" + "\n")
  o.write("k = 2" + "\n")
  for category in scores2["c normalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores2["c normalized"][category], performance["c"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores2["c normalized"][category], performance["c"]["svm precision"])) 
    + "\n")
  o.write("k = 3" + "\n")
  for category in scores3["c normalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores3["c normalized"][category], performance["c"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores3["c normalized"][category], performance["c"]["svm precision"])) 
    + "\n")
  o.write("k = 4" + "\n")
  for category in scores4["c normalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores4["c normalized"][category], performance["c"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores4["c normalized"][category], performance["c"]["svm precision"])) 
    + "\n")
  o.write("C on D" + "\n")
  o.write("k = 2" + "\n")
  for category in scores2["c normalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores2["c normalized"][category], performance["d"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores2["c normalized"][category], performance["d"]["svm precision"])) 
    + "\n")
  o.write("k = 3" + "\n")
  for category in scores3["c normalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores3["c normalized"][category], performance["d"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores3["c normalized"][category], performance["d"]["svm precision"])) 
    + "\n")
  o.write("k = 4" + "\n")
  for category in scores4["c normalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores4["c normalized"][category], performance["d"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores4["c normalized"][category], performance["d"]["svm precision"])) 
    + "\n")
  # D
  o.write("D on B" + "\n")
  o.write("k = 2" + "\n")
  for category in scores2["d normalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores2["d normalized"][category], performance["b"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores2["d normalized"][category], performance["b"]["svm precision"])) 
    + "\n")
  o.write("k = 3" + "\n")
  for category in scores3["d normalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores3["d normalized"][category], performance["b"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores3["d normalized"][category], performance["b"]["svm precision"])) 
    + "\n")
  o.write("k = 4" + "\n")
  for category in scores4["d normalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores4["d normalized"][category], performance["b"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores4["d normalized"][category], performance["b"]["svm precision"])) 
    + "\n")
  o.write("D on C" + "\n")
  o.write("k = 2" + "\n")
  for category in scores2["d normalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores2["d normalized"][category], performance["c"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores2["d normalized"][category], performance["c"]["svm precision"])) 
    + "\n")
  o.write("k = 3" + "\n")
  for category in scores3["d normalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores3["d normalized"][category], performance["c"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores3["d normalized"][category], performance["c"]["svm precision"])) 
    + "\n")
  o.write("k = 4" + "\n")
  for category in scores4["d normalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores4["d normalized"][category], performance["c"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores4["d normalized"][category], performance["c"]["svm precision"])) 
    + "\n")
  o.write("D on D" + "\n")
  o.write("k = 2" + "\n")
  for category in scores2["d normalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores2["d normalized"][category], performance["d"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores2["d normalized"][category], performance["d"]["svm precision"])) 
    + "\n")
  o.write("k = 3" + "\n")
  for category in scores3["d normalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores3["d normalized"][category], performance["d"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores3["d normalized"][category], performance["d"]["svm precision"])) 
    + "\n")
  o.write("k = 4" + "\n")
  for category in scores4["d normalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores4["d normalized"][category], performance["d"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores4["d normalized"][category], performance["d"]["svm precision"])) 
    + "\n")

# %%
# merged, 1 trial
from scipy import stats
import csv
scores2 = {"b normalized": {}, "c normalized": {}, "d normalized": {},
          "b unnormalized": {}, "c unnormalized": {}, "d unnormalized": {}}
scores3 = {"b normalized": {}, "c normalized": {}, "d normalized": {},
          "b unnormalized": {}, "c unnormalized": {}, "d unnormalized": {}}
scores4 = {"b normalized": {}, "c normalized": {}, "d normalized": {},
          "b unnormalized": {}, "c unnormalized": {}, "d unnormalized": {}}
conversion = {"du": "d unnormalized", "dn": "d normalized",
              "cu": "c unnormalized", "cn": "c normalized",
              "bu": "b unnormalized", "bn": "b normalized"}
for k in conversion.keys():
  with open(k + "2.csv", newline="") as csvfile:
    reader = csv.reader(csvfile)
    rows = [row for row in reader]
    for i in range(len(rows[0][1:])):
      scores2[conversion[k]][rows[0][i + 1]] = [float(score[i + 1]) for score in rows[1:]]
for k in conversion.keys():
  with open(k + "3.csv", newline="") as csvfile:
    reader = csv.reader(csvfile)
    rows = [row for row in reader]
    for i in range(len(rows[0][1:])):
      scores3[conversion[k]][rows[0][i + 1]] = [float(score[i + 1]) for score in rows[1:]]
for k in conversion.keys():
  with open(k + "4.csv", newline="") as csvfile:
    reader = csv.reader(csvfile)
    rows = [row for row in reader]
    for i in range(len(rows[0][1:])):
      scores4[conversion[k]][rows[0][i + 1]] = [float(score[i + 1]) for score in rows[1:]]
performance = {"b": {"svm accuracy": [0.74, 0.68, 0.78, 0.67, 0.73, 0.71, 0.83, 0.82, 0.85, 0.74,
0.81, 0.81, 0.52, 0.83, 0.82, 0.78, 0.72, 0.69, 0.81, 0.73, 0.74, 0.85, 0.7, 0.76, 0.9, 0.73, 0.84,
0.87, 0.59, 0.78, 0.73, 0.84, 0.73, 0.73, 0.72, 0.81, 0.88, 0.77, 0.74, 0.86, 0.75, 0.58, 0.8, 0.84,
0.81, 0.74, 0.79, 0.74, 0.87, 0.71, 0.77, 0.65, 0.78, 0.86, 0.68, 0.85, 0.76, 0.75, 0.53, 0.86, 0.6,
0.83, 0.81, 0.74, 0.86, 0.91, 0.73, 0.59, 0.85, 0.57, 0.38, 0.86, 0.84, 0.8, 0.71, 0.78, 0.89, 0.88,
0.8, 0.56, 0.74, 0.84, 0.71, 0.79, 0.86, 0.67, 0.63],
            "svm precision": [0.5101703534, 0.4190767974, 0.4876253133, 0.3176814585, 0.4737790301,
0.4521113481, 0.5634337068, 0.6595238095, 0.5308305486, 0.5710148769, 0.5327420424, 0.6641981181,
0.2231617647, 0.4664249685, 0.4975759535, 0.5254765843, 0.4693768038, 0.4461635587, 0.5699236425,
0.4368844697, 0.4897829666, 0.5962797619, 0.4896214467, 0.7016369048, 0.6477011494, 0.3824404762,
0.5818976222, 0.5806051587, 0.3748214286, 0.5642984467, 0.6867623604, 0.7246543779, 0.5778420523,
0.6814058957, 0.6815560027, 0.7091606134, 0.7761204482, 0.67281528, 0.6883089133, 0.6203520164,
0.4573027719, 0.3929909042, 0.6201178979, 0.7377660742, 0.7636904762, 0.5763038549, 0.6192546584,
0.5389527642, 0.7401837928, 0.5056514914, 0.7341836735, 0.6001141715, 0.7505175983, 0.7512531328,
0.5093281148, 0.7440812483, 0.6865481267, 0.5440361219, 0.1712147887, 0.6208126432, 0.428395179,
0.6039231602, 0.5657427678, 0.4839285714, 0.7454879679, 0.6365079365, 0.4726540616, 0.4168315018,
0.5544665235, 0.2104166667, 0.1793154762, 0.5856456044, 0.6732142857, 0.5433454106, 0.5183725005,
0.5572170104, 0.6314162811, 0.7398196779, 0.5786324786, 0.2883493031, 0.4292598344, 0.6044973545,
0.3902803494, 0.542742674, 0.5898122711, 0.4562287415, 0.4179743867]}, 
      "c": {"svm accuracy": [0.84, 0.85, 0.9, 0.87, 0.87, 0.95, 0.88, 0.94, 0.9, 0.94, 0.84, 0.9,
0.79, 0.9, 0.91, 0.9, 0.87, 0.92, 0.97, 0.91, 0.85, 0.91, 0.83, 0.85, 0.92, 0.9, 0.9, 0.96, 0.75,
0.96, 0.95, 0.96, 0.9, 0.92, 0.97, 0.97, 0.96, 0.92, 0.91, 0.96, 0.94, 0.85, 0.97, 0.98, 0.97, 0.94,
0.94, 0.92, 0.95, 0.94, 0.92, 0.94, 0.92, 0.99, 0.89, 0.94, 0.92, 0.9, 0.84, 0.97, 0.83, 0.92, 0.95,
0.92, 0.95, 0.96, 0.85, 0.82, 0.95, 0.85, 0.76, 0.96, 0.92, 0.9, 0.78, 0.93, 0.94, 0.94, 0.95, 0.83,
0.95, 0.94, 0.84, 0.93, 0.98, 0.8, 0.88],
            "svm precision": [0.7588908981, 0.775, 0.8576998051, 0.834717608, 0.834717608, 0.93125,
0.8341601701, 0.9095840868, 0.8862745098, 0.9404677534, 0.7588908981, 0.8576998051, 0.6647727273,
0.8493068113, 0.86875, 0.8695960312, 0.8024475524, 0.890188434, 0.9817073171, 0.8552631579,
0.7733100233, 0.8607226107, 0.7445799458, 0.7784552846, 0.9050318923, 0.8576998051, 0.8576998051,
0.955165692, 0.61875, 0.9772727273, 0.9719101124, 0.9772727273, 0.8555555556, 0.8825757576,
0.9827586207, 0.9827586207, 0.9772727273, 0.9111111111, 0.8697650664, 0.9468438538, 0.9666666667,
0.7611683849, 0.9549019608, 0.988372093, 0.9351523742, 0.9053156146, 0.9299242424, 0.9565217391,
0.9156862745, 0.9299242424, 0.9565217391, 0.9666666667, 0.9111111111, 0.9941176471, 0.8748079877,
0.9666666667, 0.9565217391, 0.8352272727, 0.7818740399, 0.9600271003, 0.7234848485, 0.8700454841,
0.9449404762, 0.8980392157, 0.9125, 0.9222423146, 0.7587719298, 0.7008547009, 0.9026806527,
0.7833333333, 0.5676392573, 0.9222423146, 0.8565782044, 0.8283455675, 0.6426250812, 0.8922764228,
0.9025341131, 0.8921036769, 0.9125, 0.7916666667, 0.9261517615, 0.8848108413, 0.7411764706,
0.9077380952, 0.9523809524, 0.6751137102, 0.8050682261]}, 
      "d": {"svm accuracy": [0.4848484848, 0.5555555556, 0.6868686869, 0.5656565657, 0.6060606061,
0.5252525253, 0.6868686869, 0.696969697, 0.6060606061, 0.6363636364, 0.6666666667, 0.6262626263,
0.1919191919, 0.6464646465, 0.6161616162, 0.6262626263, 0.5252525253, 0.595959596, 0.6565656566,
0.6666666667, 0.4848484848, 0.7070707071, 0.5555555556, 0.6565656566, 0.7575757576, 0.5353535354,
0.6161616162, 0.7070707071, 0.3333333333, 0.47, 0.5, 0.57, 0.47, 0.61, 0.45, 0.58, 0.65, 0.42, 0.56,
0.61, 0.52, 0.25, 0.51, 0.62, 0.59, 0.42, 0.57, 0.5, 0.62, 0.46, 0.47, 0.39, 0.45, 0.63, 0.52, 0.52,
0.43, 0.49, 0.19, 0.69, 0.27, 0.61, 0.71, 0.63, 0.74, 0.77, 0.5, 0.3, 0.72, 0.36, 0.17, 0.71, 0.63,
0.69, 0.43, 0.52, 0.7, 0.71, 0.64, 0.22, 0.5, 0.63, 0.32, 0.7, 0.67, 0.22, 0.44],
            "svm precision": [0.3703703704, 0.4315608466, 0.5596646185, 0.5070060208, 0.4676245211,
0.4187566138, 0.6034482759, 0.6203571429, 0.5054689755, 0.5615608466, 0.5786706349, 0.5413793103,
0.1842063492, 0.5003456221, 0.5203149002, 0.525921659, 0.386687148, 0.4698941799, 0.5558730159,
0.5708730159, 0.3678391053, 0.5978878648, 0.3953612479, 0.5863300493, 0.6082949309, 0.3923963134,
0.5448823207, 0.6119047619, 0.2868815708, 0.3824600687, 0.4173623995, 0.574137931, 0.3640059647,
0.440138597, 0.4229064039, 0.5374832064, 0.5524630542, 0.3400088417, 0.5321428571, 0.5448554422,
0.4771441202, 0.2788919414, 0.4318007663, 0.558106576, 0.5306986117, 0.4111166611, 0.5801870748,
0.4551450465, 0.5027910053, 0.3240968801, 0.4850122558, 0.3175287356, 0.4845155993, 0.6277367269,
0.3714760617, 0.4754789272, 0.3678633627, 0.4845427561, 0.1082173825, 0.6469444444, 0.2478774929,
0.5229885057, 0.6004291685, 0.5454980843, 0.6940512266, 0.7171592775, 0.4125661376, 0.2897214854,
0.6712643678, 0.3002663046, 0.09778325123, 0.5956486043, 0.5175175399, 0.6548440066, 0.3844827586,
0.4186445738, 0.6411772487, 0.5910509031, 0.5943518519, 0.1537037037, 0.4288888889, 0.5215367965,
0.2235109718, 0.630952381, 0.5114121511, 0.1848522167, 0.3806940186]}}
with open("unnormalizedmerged1.txt", "w") as o:
  o.write("B on B" + "\n")
  o.write("k = 2" + "\n")
  for category in scores2["b unnormalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores2["b unnormalized"][category], performance["b"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores2["b unnormalized"][category], performance["b"]["svm precision"])) 
    + "\n")
  o.write("k = 3" + "\n")
  for category in scores3["b unnormalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores3["b unnormalized"][category], performance["b"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores3["b unnormalized"][category], performance["b"]["svm precision"])) 
    + "\n")
  o.write("k = 4" + "\n")
  for category in scores4["b unnormalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores4["b unnormalized"][category], performance["b"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores4["b unnormalized"][category], performance["b"]["svm precision"])) 
    + "\n")
  o.write("B on C" + "\n")
  o.write("k = 2" + "\n")
  for category in scores2["b unnormalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores2["b unnormalized"][category], performance["c"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores2["b unnormalized"][category], performance["c"]["svm precision"])) 
    + "\n")
  o.write("k = 3" + "\n")
  for category in scores3["b unnormalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores3["b unnormalized"][category], performance["c"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores3["b unnormalized"][category], performance["c"]["svm precision"])) 
    + "\n")
  o.write("k = 4" + "\n")
  for category in scores4["b unnormalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores4["b unnormalized"][category], performance["c"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores4["b unnormalized"][category], performance["c"]["svm precision"])) 
    + "\n")
  o.write("B on D" + "\n")
  o.write("k = 2" + "\n")
  for category in scores2["b unnormalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores2["b unnormalized"][category], performance["d"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores2["b unnormalized"][category], performance["d"]["svm precision"]))
    + "\n") 
  o.write("k = 3" + "\n")
  for category in scores3["b unnormalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores3["b unnormalized"][category], performance["d"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores3["b unnormalized"][category], performance["d"]["svm precision"])) 
    + "\n")
  o.write("k = 4" + "\n")
  for category in scores4["b unnormalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores4["b unnormalized"][category], performance["d"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores4["b unnormalized"][category], performance["d"]["svm precision"])) 
    + "\n")
  # C
  o.write("C on B" + "\n")
  o.write("k = 2" + "\n")
  for category in scores2["c unnormalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores2["c unnormalized"][category], performance["b"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores2["c unnormalized"][category], performance["b"]["svm precision"])) 
    + "\n")
  o.write("k = 3" + "\n")
  for category in scores3["c unnormalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores3["c unnormalized"][category], performance["b"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores3["c unnormalized"][category], performance["b"]["svm precision"])) 
    + "\n")
  o.write("k = 4" + "\n")
  for category in scores4["c unnormalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores4["c unnormalized"][category], performance["b"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores4["c unnormalized"][category], performance["b"]["svm precision"])) 
    + "\n")
  o.write("C on C" + "\n")
  o.write("k = 2" + "\n")
  for category in scores2["c unnormalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores2["c unnormalized"][category], performance["c"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores2["c unnormalized"][category], performance["c"]["svm precision"])) 
    + "\n")
  o.write("k = 3" + "\n")
  for category in scores3["c unnormalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores3["c unnormalized"][category], performance["c"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores3["c unnormalized"][category], performance["c"]["svm precision"])) 
    + "\n")
  o.write("k = 4" + "\n")
  for category in scores4["c unnormalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores4["c unnormalized"][category], performance["c"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores4["c unnormalized"][category], performance["c"]["svm precision"])) 
    + "\n")
  o.write("C on D" + "\n")
  o.write("k = 2" + "\n")
  for category in scores2["c unnormalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores2["c unnormalized"][category], performance["d"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores2["c unnormalized"][category], performance["d"]["svm precision"])) 
    + "\n")
  o.write("k = 3" + "\n")
  for category in scores3["c unnormalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores3["c unnormalized"][category], performance["d"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores3["c unnormalized"][category], performance["d"]["svm precision"])) 
    + "\n")
  o.write("k = 4" + "\n")
  for category in scores4["c unnormalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores4["c unnormalized"][category], performance["d"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores4["c unnormalized"][category], performance["d"]["svm precision"])) 
    + "\n")
  # D
  o.write("D on B" + "\n")
  o.write("k = 2" + "\n")
  for category in scores2["d unnormalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores2["d unnormalized"][category], performance["b"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores2["d unnormalized"][category], performance["b"]["svm precision"])) 
    + "\n")
  o.write("k = 3" + "\n")
  for category in scores3["d unnormalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores3["d unnormalized"][category], performance["b"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores3["d unnormalized"][category], performance["b"]["svm precision"])) 
    + "\n")
  o.write("k = 4" + "\n")
  for category in scores4["d unnormalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores4["d unnormalized"][category], performance["b"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores4["d unnormalized"][category], performance["b"]["svm precision"])) 
    + "\n")
  o.write("D on C" + "\n")
  o.write("k = 2" + "\n")
  for category in scores2["d unnormalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores2["d unnormalized"][category], performance["c"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores2["d unnormalized"][category], performance["c"]["svm precision"])) 
    + "\n")
  o.write("k = 3" + "\n")
  for category in scores3["d unnormalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores3["d unnormalized"][category], performance["c"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores3["d unnormalized"][category], performance["c"]["svm precision"])) 
    + "\n")
  o.write("k = 4" + "\n")
  for category in scores4["d unnormalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores4["d unnormalized"][category], performance["c"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores4["d unnormalized"][category], performance["c"]["svm precision"])) 
    + "\n")
  o.write("D on D" + "\n")
  o.write("k = 2" + "\n")
  for category in scores2["d unnormalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores2["d unnormalized"][category], performance["d"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores2["d unnormalized"][category], performance["d"]["svm precision"])) 
    + "\n")
  o.write("k = 3" + "\n")
  for category in scores3["d unnormalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores3["d unnormalized"][category], performance["d"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores3["d unnormalized"][category], performance["d"]["svm precision"])) 
    + "\n")
  o.write("k = 4" + "\n")
  for category in scores4["d unnormalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores4["d unnormalized"][category], performance["d"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores4["d unnormalized"][category], performance["d"]["svm precision"])) 
    + "\n")


with open("normalizedmerged1.txt", "w") as o:
  o.write("B on B" + "\n")
  o.write("k = 2" + "\n")
  for category in scores2["b normalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores2["b normalized"][category], performance["b"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores2["b normalized"][category], performance["b"]["svm precision"])) 
    + "\n")
  o.write("k = 3" + "\n")
  for category in scores3["b normalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores3["b normalized"][category], performance["b"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores3["b normalized"][category], performance["b"]["svm precision"])) 
    + "\n")
  o.write("k = 4" + "\n")
  for category in scores4["b normalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores4["b normalized"][category], performance["b"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores4["b normalized"][category], performance["b"]["svm precision"])) 
    + "\n")
  o.write("B on C" + "\n")
  o.write("k = 2" + "\n")
  for category in scores2["b normalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores2["b normalized"][category], performance["c"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores2["b normalized"][category], performance["c"]["svm precision"])) 
    + "\n")
  o.write("k = 3" + "\n")
  for category in scores3["b normalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores3["b normalized"][category], performance["c"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores3["b normalized"][category], performance["c"]["svm precision"])) 
    + "\n")
  o.write("k = 4" + "\n")
  for category in scores4["b normalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores4["b normalized"][category], performance["c"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores4["b normalized"][category], performance["c"]["svm precision"])) 
    + "\n")
  o.write("B on D" + "\n")
  o.write("k = 2" + "\n")
  for category in scores2["b normalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores2["b normalized"][category], performance["d"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores2["b normalized"][category], performance["d"]["svm precision"])) 
    + "\n")
  o.write("k = 3" + "\n")
  for category in scores3["b normalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores3["b normalized"][category], performance["d"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores3["b normalized"][category], performance["d"]["svm precision"])) 
    + "\n")
  o.write("k = 4" + "\n")
  for category in scores4["b normalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores4["b normalized"][category], performance["d"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores4["b normalized"][category], performance["d"]["svm precision"])) 
    + "\n")
  # C
  o.write("C on B" + "\n")
  o.write("k = 2" + "\n")
  for category in scores2["c normalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores2["c normalized"][category], performance["b"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores2["c normalized"][category], performance["b"]["svm precision"])) 
    + "\n")
  o.write("k = 3" + "\n")
  for category in scores3["c normalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores3["c normalized"][category], performance["b"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores3["c normalized"][category], performance["b"]["svm precision"])) 
    + "\n")
  o.write("k = 4" + "\n")
  for category in scores4["c normalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores4["c normalized"][category], performance["b"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores4["c normalized"][category], performance["b"]["svm precision"])) 
    + "\n")
  o.write("C on C" + "\n")
  o.write("k = 2" + "\n")
  for category in scores2["c normalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores2["c normalized"][category], performance["c"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores2["c normalized"][category], performance["c"]["svm precision"])) 
    + "\n")
  o.write("k = 3" + "\n")
  for category in scores3["c normalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores3["c normalized"][category], performance["c"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores3["c normalized"][category], performance["c"]["svm precision"])) 
    + "\n")
  o.write("k = 4" + "\n")
  for category in scores4["c normalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores4["c normalized"][category], performance["c"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores4["c normalized"][category], performance["c"]["svm precision"])) 
    + "\n")
  o.write("C on D" + "\n")
  o.write("k = 2" + "\n")
  for category in scores2["c normalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores2["c normalized"][category], performance["d"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores2["c normalized"][category], performance["d"]["svm precision"])) 
    + "\n")
  o.write("k = 3" + "\n")
  for category in scores3["c normalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores3["c normalized"][category], performance["d"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores3["c normalized"][category], performance["d"]["svm precision"])) 
    + "\n")
  o.write("k = 4" + "\n")
  for category in scores4["c normalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores4["c normalized"][category], performance["d"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores4["c normalized"][category], performance["d"]["svm precision"])) 
    + "\n")
  # D
  o.write("D on B" + "\n")
  o.write("k = 2" + "\n")
  for category in scores2["d normalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores2["d normalized"][category], performance["b"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores2["d normalized"][category], performance["b"]["svm precision"])) 
    + "\n")
  o.write("k = 3" + "\n")
  for category in scores3["d normalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores3["d normalized"][category], performance["b"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores3["d normalized"][category], performance["b"]["svm precision"])) 
    + "\n")
  o.write("k = 4" + "\n")
  for category in scores4["d normalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores4["d normalized"][category], performance["b"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores4["d normalized"][category], performance["b"]["svm precision"])) 
    + "\n")
  o.write("D on C" + "\n")
  o.write("k = 2" + "\n")
  for category in scores2["d normalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores2["d normalized"][category], performance["c"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores2["d normalized"][category], performance["c"]["svm precision"])) 
    + "\n")
  o.write("k = 3" + "\n")
  for category in scores3["d normalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores3["d normalized"][category], performance["c"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores3["d normalized"][category], performance["c"]["svm precision"])) 
    + "\n")
  o.write("k = 4" + "\n")
  for category in scores4["d normalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores4["d normalized"][category], performance["c"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores4["d normalized"][category], performance["c"]["svm precision"])) 
    + "\n")
  o.write("D on D" + "\n")
  o.write("k = 2" + "\n")
  for category in scores2["d normalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores2["d normalized"][category], performance["d"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores2["d normalized"][category], performance["d"]["svm precision"])) 
    + "\n")
  o.write("k = 3" + "\n")
  for category in scores3["d normalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores3["d normalized"][category], performance["d"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores3["d normalized"][category], performance["d"]["svm precision"])) 
    + "\n")
  o.write("k = 4" + "\n")
  for category in scores4["d normalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores4["d normalized"][category], performance["d"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores4["d normalized"][category], performance["d"]["svm precision"])) 
    + "\n")

# %%
# merged, 30 trials
from scipy import stats
import csv
scores2 = {"b normalized": {}, "c normalized": {}, "d normalized": {},
          "b unnormalized": {}, "c unnormalized": {}, "d unnormalized": {}}
scores3 = {"b normalized": {}, "c normalized": {}, "d normalized": {},
          "b unnormalized": {}, "c unnormalized": {}, "d unnormalized": {}}
scores4 = {"b normalized": {}, "c normalized": {}, "d normalized": {},
          "b unnormalized": {}, "c unnormalized": {}, "d unnormalized": {}}
conversion = {"du": "d unnormalized", "dn": "d normalized",
              "cu": "c unnormalized", "cn": "c normalized",
              "bu": "b unnormalized", "bn": "b normalized"}
for k in conversion.keys():
  with open(k + "2.csv", newline="") as csvfile:
    reader = csv.reader(csvfile)
    rows = [row for row in reader]
    for i in range(len(rows[0][1:])):
      scores2[conversion[k]][rows[0][i + 1]] = [float(score[i + 1]) for score in rows[1:]]
for k in conversion.keys():
  with open(k + "3.csv", newline="") as csvfile:
    reader = csv.reader(csvfile)
    rows = [row for row in reader]
    for i in range(len(rows[0][1:])):
      scores3[conversion[k]][rows[0][i + 1]] = [float(score[i + 1]) for score in rows[1:]]
for k in conversion.keys():
  with open(k + "4.csv", newline="") as csvfile:
    reader = csv.reader(csvfile)
    rows = [row for row in reader]
    for i in range(len(rows[0][1:])):
      scores4[conversion[k]][rows[0][i + 1]] = [float(score[i + 1]) for score in rows[1:]]
performance = {"b": {"svm accuracy": [0.7673703704, 0.7463299663, 0.8385420875, 0.767037037,
0.7904141414, 0.7205589226, 0.857959596, 0.8713468013, 0.7850942761, 0.7934612795, 0.8285420875,
0.8052188552, 0.48996633, 0.8131481481, 0.7941178451, 0.8037676768, 0.751996633, 0.752020202,
0.8382424242, 0.8248956229, 0.7426599327, 0.864969697, 0.7179259259, 0.7944276094, 0.8863670034,
0.7359393939, 0.8308619529, 0.8342188552, 0.616956229, 0.7394343434, 0.7434713805, 0.8189191919,
0.7187373737, 0.7440639731, 0.7337407407, 0.8175791246, 0.87103367, 0.7527845118, 0.7397710438,
0.8258989899, 0.7417811448, 0.5820942761, 0.7848484848, 0.8182828283, 0.7988821549, 0.7136734007,
0.7544478114, 0.7591144781, 0.8192929293, 0.7230572391, 0.7741582492, 0.695010101, 0.7494781145,
0.8667138047, 0.7207441077, 0.8015656566, 0.7434276094, 0.7224276094, 0.5482929293, 0.8398451178,
0.6389427609, 0.8381548822, 0.8234242424, 0.7829427609, 0.900037037, 0.9056632997, 0.7254680135,
0.6000740741, 0.8608720539, 0.563979798, 0.4185319865, 0.8725757576, 0.8173939394, 0.8331481481,
0.7445959596, 0.788959596, 0.8722558923, 0.8729292929, 0.7943434343, 0.5573569024, 0.7863164983,
0.8605690236, 0.6586228956, 0.8217340067, 0.883969697, 0.6476262626, 0.6923804714],
            "svm precision": [0.5464727939, 0.5377880621, 0.6534597223, 0.5780594388, 0.5907848568,
0.5226709456, 0.6457177645, 0.7119076314, 0.5749471763, 0.6495865697, 0.6494690692, 0.6160726757,
0.2520649922, 0.5990372326, 0.5808536863, 0.6490800984, 0.5940517202, 0.558948451, 0.6745174116,
0.6733482418, 0.5858530787, 0.681696211, 0.5104926695, 0.6460162671, 0.6971797383, 0.5612774072,
0.6420604534, 0.6527046011, 0.3899390852, 0.5147425425, 0.5474948429, 0.6402944964, 0.5126869184,
0.5613977843, 0.537132228, 0.62617972, 0.697997719, 0.5817829722, 0.6274076805, 0.6394641556,
0.5250325671, 0.3951158418, 0.6434601865, 0.5809606837, 0.6377273618, 0.6015585221, 0.5759866704,
0.5839562862, 0.6504294501, 0.5605764817, 0.5606690411, 0.5094513485, 0.6258969468, 0.7171399857,
0.5373588033, 0.5863675111, 0.5576247718, 0.4906650285, 0.3292417684, 0.622055043, 0.4210915687,
0.6455527631, 0.6488459412, 0.5935201586, 0.7193452882, 0.7440730631, 0.4924639685, 0.4015354397,
0.6482095003, 0.2524556341, 0.194138624, 0.7034911759, 0.6196898253, 0.7120516625, 0.5836523684,
0.5989398641, 0.6933248633, 0.722120457, 0.6147424574, 0.2868046426, 0.5904331695, 0.7423450081,
0.4632996523, 0.6564408253, 0.6789269745, 0.4737179017, 0.459611614]}, 
      "c": {"svm accuracy": [0.8763400673, 0.8826801347, 0.9198047138, 0.8780572391, 0.9091077441,
0.872979798, 0.9304747475, 0.9364949495, 0.9070808081, 0.9000942761, 0.9091077441, 0.9001111111,
0.7443232323, 0.9137676768, 0.9137912458, 0.9034074074, 0.8773468013, 0.9047710438, 0.9234848485,
0.9017609428, 0.8783737374, 0.9257946128, 0.8646430976, 0.8753501684, 0.9378552189, 0.8923905724,
0.8863771044, 0.9221380471, 0.8045521886, 0.9115117845, 0.9008619529, 0.9272424242, 0.9131885522,
0.9172289562, 0.9148888889, 0.9365757576, 0.9486026936, 0.9132188552, 0.9075117845, 0.9258888889,
0.9105454545, 0.8227306397, 0.9385757576, 0.9339090909, 0.9259057239, 0.9222356902, 0.9088619529,
0.9155286195, 0.9315757576, 0.8955252525, 0.9232222222, 0.8908383838, 0.8951986532, 0.9436060606,
0.8982053872, 0.9145286195, 0.9262289562, 0.8818047138, 0.8050673401, 0.9389124579, 0.8140909091,
0.9095521886, 0.9312188552, 0.9171986532, 0.9545993266, 0.9489393939, 0.8527676768, 0.8217205387,
0.9429090909, 0.8184107744, 0.741969697, 0.9385892256, 0.9429360269, 0.9185723906, 0.8617946128,
0.9108585859, 0.9465925926, 0.9238989899, 0.9215454545, 0.8253973064, 0.8944882155, 0.9328989899,
0.8377912458, 0.9405824916, 0.9419124579, 0.7816565657, 0.8247171717],
            "svm precision": [0.806782194, 0.8114913366, 0.8819106968, 0.8061546368, 0.8572243655,
0.7964645835, 0.8890861172, 0.9037432513, 0.8559372566, 0.8423619914, 0.8566965026, 0.8437733434,
0.5740093462, 0.8612944814, 0.8679272473, 0.8533264654, 0.808455226, 0.8531786127, 0.8861563599,
0.8448151212, 0.8043139448, 0.8869307513, 0.7829614458, 0.8003360301, 0.9045145727, 0.8272563165,
0.8225562593, 0.8822261985, 0.6718035062, 0.897825603, 0.8713204013, 0.9256472319, 0.9146828206,
0.9009023001, 0.9087182426, 0.931490078, 0.9516104885, 0.9025356258, 0.8939500887, 0.9160238603,
0.8975107206, 0.7177907782, 0.9337669811, 0.9150639428, 0.9147005825, 0.9281775487, 0.9039012088,
0.9332942971, 0.9190953523, 0.8724923911, 0.9200006485, 0.8713990654, 0.8796500718, 0.9546340743,
0.8940336208, 0.9047014374, 0.9529267728, 0.8363634304, 0.666078723, 0.9102840941, 0.6978404053,
0.857304944, 0.8995878671, 0.8809442121, 0.9423061378, 0.9262121274, 0.7635568678, 0.71222342,
0.9211439142, 0.6972174913, 0.5587052028, 0.9070074558, 0.9291739034, 0.8749253392, 0.7801795394,
0.8748836668, 0.9351163172, 0.884024839, 0.8779159133, 0.7312576134, 0.8424026595, 0.9127701691,
0.7423317596, 0.9223403348, 0.9173951196, 0.6524950366, 0.7201602564]}, 
      "d": {"svm accuracy": [0.5157643098, 0.590969697, 0.6291010101, 0.5291212121, 0.5973164983,
0.5461313131, 0.6431043771, 0.6672424242, 0.5789124579, 0.6260808081, 0.6485050505, 0.6107306397,
0.1818619529, 0.6317508418, 0.6258013468, 0.609020202, 0.5251313131, 0.5766329966, 0.6421582492,
0.615026936, 0.5091043771, 0.6665589226, 0.509020202, 0.5735892256, 0.6668956229, 0.5555353535,
0.5966464646, 0.6478316498, 0.3611784512, 0.4828181818, 0.5272424242, 0.6167407407, 0.4851885522,
0.5028821549, 0.5526228956, 0.6300808081, 0.6791515152, 0.4998585859, 0.5161986532, 0.6290774411,
0.5202390572, 0.2176902357, 0.5662962963, 0.6351043771, 0.5826700337, 0.5058518519, 0.538962963,
0.5025454545, 0.6023434343, 0.4534309764, 0.5208922559, 0.4484276094, 0.4731717172, 0.6561279461,
0.4911784512, 0.5662996633, 0.4848215488, 0.5161717172, 0.1837845118, 0.6754444444, 0.2978754209,
0.6417575758, 0.6667777778, 0.6094040404, 0.7431582492, 0.7538316498, 0.4763164983, 0.2915286195,
0.7027845118, 0.3005319865, 0.1417508418, 0.7108181818, 0.6544175084, 0.6774410774, 0.4546262626,
0.575043771, 0.6921111111, 0.6904511785, 0.6274040404, 0.2471818182, 0.5396868687, 0.6337676768,
0.3905723906, 0.6561346801, 0.6921077441, 0.2618653199, 0.458969697],
            "svm precision": [0.4102556406, 0.4667136909, 0.5446862207, 0.4291789973, 0.4996698388,
0.4405435036, 0.5493448149, 0.5662858518, 0.4758947154, 0.5064977119, 0.5487233569, 0.5242397881,
0.1497843112, 0.4962646326, 0.5227193425, 0.4973395611, 0.4272808454, 0.4628620906, 0.5411724042,
0.5217481426, 0.4136969768, 0.5701962427, 0.3988559828, 0.4897167993, 0.5781504414, 0.4519258581,
0.4956309342, 0.551043068, 0.3077475294, 0.3967611835, 0.406490262, 0.5356452402, 0.4312518178,
0.4448020409, 0.4154506511, 0.5193483822, 0.5367970787, 0.4241632703, 0.4538746826, 0.4910612437,
0.4349008885, 0.2387549638, 0.4877843385, 0.515831218, 0.4784900631, 0.4320133245, 0.4402419238,
0.4290912667, 0.486993653, 0.3792931449, 0.4688426068, 0.3822483611, 0.4366582397, 0.5535475846,
0.4200121244, 0.4815876177, 0.4484124253, 0.4192702599, 0.1363619673, 0.5556054003, 0.251698478,
0.5160965612, 0.5587915054, 0.4991818515, 0.6434115208, 0.64327269, 0.3800034255, 0.2295970382,
0.6083757591, 0.2238165352, 0.1202849886, 0.5852762848, 0.5373341061, 0.5798170637, 0.3901647286,
0.4598649089, 0.5928973265, 0.6149538167, 0.5052153383, 0.1711280495, 0.4313569686, 0.5405750343,
0.2878409461, 0.5441337093, 0.5704337764, 0.2224415947, 0.3562775872]}}
with open("unnormalizedmerged30.txt", "w") as o:
  o.write("B on B" + "\n")
  o.write("k = 2" + "\n")
  for category in scores2["b unnormalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores2["b unnormalized"][category], performance["b"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores2["b unnormalized"][category], performance["b"]["svm precision"])) 
    + "\n")
  o.write("k = 3" + "\n")
  for category in scores3["b unnormalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores3["b unnormalized"][category], performance["b"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores3["b unnormalized"][category], performance["b"]["svm precision"])) 
    + "\n")
  o.write("k = 4" + "\n")
  for category in scores4["b unnormalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores4["b unnormalized"][category], performance["b"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores4["b unnormalized"][category], performance["b"]["svm precision"])) 
    + "\n")
  o.write("B on C" + "\n")
  o.write("k = 2" + "\n")
  for category in scores2["b unnormalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores2["b unnormalized"][category], performance["c"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores2["b unnormalized"][category], performance["c"]["svm precision"])) 
    + "\n")
  o.write("k = 3" + "\n")
  for category in scores3["b unnormalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores3["b unnormalized"][category], performance["c"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores3["b unnormalized"][category], performance["c"]["svm precision"])) 
    + "\n")
  o.write("k = 4" + "\n")
  for category in scores4["b unnormalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores4["b unnormalized"][category], performance["c"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores4["b unnormalized"][category], performance["c"]["svm precision"])) 
    + "\n")
  o.write("B on D" + "\n")
  o.write("k = 2" + "\n")
  for category in scores2["b unnormalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores2["b unnormalized"][category], performance["d"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores2["b unnormalized"][category], performance["d"]["svm precision"]))
    + "\n") 
  o.write("k = 3" + "\n")
  for category in scores3["b unnormalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores3["b unnormalized"][category], performance["d"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores3["b unnormalized"][category], performance["d"]["svm precision"])) 
    + "\n")
  o.write("k = 4" + "\n")
  for category in scores4["b unnormalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores4["b unnormalized"][category], performance["d"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores4["b unnormalized"][category], performance["d"]["svm precision"])) 
    + "\n")
  # C
  o.write("C on B" + "\n")
  o.write("k = 2" + "\n")
  for category in scores2["c unnormalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores2["c unnormalized"][category], performance["b"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores2["c unnormalized"][category], performance["b"]["svm precision"])) 
    + "\n")
  o.write("k = 3" + "\n")
  for category in scores3["c unnormalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores3["c unnormalized"][category], performance["b"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores3["c unnormalized"][category], performance["b"]["svm precision"])) 
    + "\n")
  o.write("k = 4" + "\n")
  for category in scores4["c unnormalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores4["c unnormalized"][category], performance["b"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores4["c unnormalized"][category], performance["b"]["svm precision"])) 
    + "\n")
  o.write("C on C" + "\n")
  o.write("k = 2" + "\n")
  for category in scores2["c unnormalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores2["c unnormalized"][category], performance["c"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores2["c unnormalized"][category], performance["c"]["svm precision"])) 
    + "\n")
  o.write("k = 3" + "\n")
  for category in scores3["c unnormalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores3["c unnormalized"][category], performance["c"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores3["c unnormalized"][category], performance["c"]["svm precision"])) 
    + "\n")
  o.write("k = 4" + "\n")
  for category in scores4["c unnormalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores4["c unnormalized"][category], performance["c"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores4["c unnormalized"][category], performance["c"]["svm precision"])) 
    + "\n")
  o.write("C on D" + "\n")
  o.write("k = 2" + "\n")
  for category in scores2["c unnormalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores2["c unnormalized"][category], performance["d"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores2["c unnormalized"][category], performance["d"]["svm precision"])) 
    + "\n")
  o.write("k = 3" + "\n")
  for category in scores3["c unnormalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores3["c unnormalized"][category], performance["d"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores3["c unnormalized"][category], performance["d"]["svm precision"])) 
    + "\n")
  o.write("k = 4" + "\n")
  for category in scores4["c unnormalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores4["c unnormalized"][category], performance["d"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores4["c unnormalized"][category], performance["d"]["svm precision"])) 
    + "\n")
  # D
  o.write("D on B" + "\n")
  o.write("k = 2" + "\n")
  for category in scores2["d unnormalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores2["d unnormalized"][category], performance["b"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores2["d unnormalized"][category], performance["b"]["svm precision"])) 
    + "\n")
  o.write("k = 3" + "\n")
  for category in scores3["d unnormalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores3["d unnormalized"][category], performance["b"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores3["d unnormalized"][category], performance["b"]["svm precision"])) 
    + "\n")
  o.write("k = 4" + "\n")
  for category in scores4["d unnormalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores4["d unnormalized"][category], performance["b"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores4["d unnormalized"][category], performance["b"]["svm precision"])) 
    + "\n")
  o.write("D on C" + "\n")
  o.write("k = 2" + "\n")
  for category in scores2["d unnormalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores2["d unnormalized"][category], performance["c"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores2["d unnormalized"][category], performance["c"]["svm precision"])) 
    + "\n")
  o.write("k = 3" + "\n")
  for category in scores3["d unnormalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores3["d unnormalized"][category], performance["c"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores3["d unnormalized"][category], performance["c"]["svm precision"])) 
    + "\n")
  o.write("k = 4" + "\n")
  for category in scores4["d unnormalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores4["d unnormalized"][category], performance["c"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores4["d unnormalized"][category], performance["c"]["svm precision"])) 
    + "\n")
  o.write("D on D" + "\n")
  o.write("k = 2" + "\n")
  for category in scores2["d unnormalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores2["d unnormalized"][category], performance["d"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores2["d unnormalized"][category], performance["d"]["svm precision"])) 
    + "\n")
  o.write("k = 3" + "\n")
  for category in scores3["d unnormalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores3["d unnormalized"][category], performance["d"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores3["d unnormalized"][category], performance["d"]["svm precision"])) 
    + "\n")
  o.write("k = 4" + "\n")
  for category in scores4["d unnormalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores4["d unnormalized"][category], performance["d"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores4["d unnormalized"][category], performance["d"]["svm precision"])) 
    + "\n")


with open("normalizedmerged30.txt", "w") as o:
  o.write("B on B" + "\n")
  o.write("k = 2" + "\n")
  for category in scores2["b normalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores2["b normalized"][category], performance["b"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores2["b normalized"][category], performance["b"]["svm precision"])) 
    + "\n")
  o.write("k = 3" + "\n")
  for category in scores3["b normalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores3["b normalized"][category], performance["b"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores3["b normalized"][category], performance["b"]["svm precision"])) 
    + "\n")
  o.write("k = 4" + "\n")
  for category in scores4["b normalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores4["b normalized"][category], performance["b"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores4["b normalized"][category], performance["b"]["svm precision"])) 
    + "\n")
  o.write("B on C" + "\n")
  o.write("k = 2" + "\n")
  for category in scores2["b normalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores2["b normalized"][category], performance["c"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores2["b normalized"][category], performance["c"]["svm precision"])) 
    + "\n")
  o.write("k = 3" + "\n")
  for category in scores3["b normalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores3["b normalized"][category], performance["c"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores3["b normalized"][category], performance["c"]["svm precision"])) 
    + "\n")
  o.write("k = 4" + "\n")
  for category in scores4["b normalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores4["b normalized"][category], performance["c"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores4["b normalized"][category], performance["c"]["svm precision"])) 
    + "\n")
  o.write("B on D" + "\n")
  o.write("k = 2" + "\n")
  for category in scores2["b normalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores2["b normalized"][category], performance["d"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores2["b normalized"][category], performance["d"]["svm precision"])) 
    + "\n")
  o.write("k = 3" + "\n")
  for category in scores3["b normalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores3["b normalized"][category], performance["d"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores3["b normalized"][category], performance["d"]["svm precision"])) 
    + "\n")
  o.write("k = 4" + "\n")
  for category in scores4["b normalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores4["b normalized"][category], performance["d"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores4["b normalized"][category], performance["d"]["svm precision"])) 
    + "\n")
  # C
  o.write("C on B" + "\n")
  o.write("k = 2" + "\n")
  for category in scores2["c normalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores2["c normalized"][category], performance["b"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores2["c normalized"][category], performance["b"]["svm precision"])) 
    + "\n")
  o.write("k = 3" + "\n")
  for category in scores3["c normalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores3["c normalized"][category], performance["b"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores3["c normalized"][category], performance["b"]["svm precision"])) 
    + "\n")
  o.write("k = 4" + "\n")
  for category in scores4["c normalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores4["c normalized"][category], performance["b"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores4["c normalized"][category], performance["b"]["svm precision"])) 
    + "\n")
  o.write("C on C" + "\n")
  o.write("k = 2" + "\n")
  for category in scores2["c normalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores2["c normalized"][category], performance["c"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores2["c normalized"][category], performance["c"]["svm precision"])) 
    + "\n")
  o.write("k = 3" + "\n")
  for category in scores3["c normalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores3["c normalized"][category], performance["c"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores3["c normalized"][category], performance["c"]["svm precision"])) 
    + "\n")
  o.write("k = 4" + "\n")
  for category in scores4["c normalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores4["c normalized"][category], performance["c"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores4["c normalized"][category], performance["c"]["svm precision"])) 
    + "\n")
  o.write("C on D" + "\n")
  o.write("k = 2" + "\n")
  for category in scores2["c normalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores2["c normalized"][category], performance["d"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores2["c normalized"][category], performance["d"]["svm precision"])) 
    + "\n")
  o.write("k = 3" + "\n")
  for category in scores3["c normalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores3["c normalized"][category], performance["d"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores3["c normalized"][category], performance["d"]["svm precision"])) 
    + "\n")
  o.write("k = 4" + "\n")
  for category in scores4["c normalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores4["c normalized"][category], performance["d"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores4["c normalized"][category], performance["d"]["svm precision"])) 
    + "\n")
  # D
  o.write("D on B" + "\n")
  o.write("k = 2" + "\n")
  for category in scores2["d normalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores2["d normalized"][category], performance["b"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores2["d normalized"][category], performance["b"]["svm precision"])) 
    + "\n")
  o.write("k = 3" + "\n")
  for category in scores3["d normalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores3["d normalized"][category], performance["b"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores3["d normalized"][category], performance["b"]["svm precision"])) 
    + "\n")
  o.write("k = 4" + "\n")
  for category in scores4["d normalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores4["d normalized"][category], performance["b"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores4["d normalized"][category], performance["b"]["svm precision"])) 
    + "\n")
  o.write("D on C" + "\n")
  o.write("k = 2" + "\n")
  for category in scores2["d normalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores2["d normalized"][category], performance["c"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores2["d normalized"][category], performance["c"]["svm precision"])) 
    + "\n")
  o.write("k = 3" + "\n")
  for category in scores3["d normalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores3["d normalized"][category], performance["c"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores3["d normalized"][category], performance["c"]["svm precision"])) 
    + "\n")
  o.write("k = 4" + "\n")
  for category in scores4["d normalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores4["d normalized"][category], performance["c"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores4["d normalized"][category], performance["c"]["svm precision"])) 
    + "\n")
  o.write("D on D" + "\n")
  o.write("k = 2" + "\n")
  for category in scores2["d normalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores2["d normalized"][category], performance["d"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores2["d normalized"][category], performance["d"]["svm precision"])) 
    + "\n")
  o.write("k = 3" + "\n")
  for category in scores3["d normalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores3["d normalized"][category], performance["d"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores3["d normalized"][category], performance["d"]["svm precision"])) 
    + "\n")
  o.write("k = 4" + "\n")
  for category in scores4["d normalized"].keys():
    o.write(category + "\n")
    o.write("svm accuracy" + "\n")
    o.write(str(stats.spearmanr(scores4["d normalized"][category], performance["d"]["svm accuracy"]))
     + "\n")
    o.write("svm precision" + "\n")
    o.write(str(stats.spearmanr(scores4["d normalized"][category], performance["d"]["svm precision"])) 
    + "\n")

# %%
# movies, 1 trial
from scipy import stats
import csv
scores2 = {"b normalized": {}, "c normalized": {}, "d normalized": {},
          "b unnormalized": {}, "c unnormalized": {}, "d unnormalized": {}}
scores3 = {"b normalized": {}, "c normalized": {}, "d normalized": {},
          "b unnormalized": {}, "c unnormalized": {}, "d unnormalized": {}}
scores4 = {"b normalized": {}, "c normalized": {}, "d normalized": {},
          "b unnormalized": {}, "c unnormalized": {}, "d unnormalized": {}}
conversion = {"du": "d unnormalized", "dn": "d normalized",
              "cu": "c unnormalized", "cn": "c normalized",
              "bu": "b unnormalized", "bn": "b normalized"}
for k in conversion.keys():
  with open(k + "2.csv", newline="") as csvfile:
    reader = csv.reader(csvfile)
    rows = [row for row in reader]
    for i in range(len(rows[0][1:])):
      scores2[conversion[k]][rows[0][i + 1]] = [float(score[i + 1]) for score in rows[1:]]
for k in conversion.keys():
  with open(k + "3.csv", newline="") as csvfile:
    reader = csv.reader(csvfile)
    rows = [row for row in reader]
    for i in range(len(rows[0][1:])):
      scores3[conversion[k]][rows[0][i + 1]] = [float(score[i + 1]) for score in rows[1:]]
for k in conversion.keys():
  with open(k + "4.csv", newline="") as csvfile:
    reader = csv.reader(csvfile)
    rows = [row for row in reader]
    for i in range(len(rows[0][1:])):
      scores4[conversion[k]][rows[0][i + 1]] = [float(score[i + 1]) for score in rows[1:]]
performance = {"accuracy": [0.7625, 0.776, 0.77, 0.757, 0.785, 0.768, 0.774, 0.7855, 0.7725, 0.773,
0.78, 0.7775, 0.7705, 0.7905, 0.794, 0.7925, 0.7645, 0.7425, 0.756, 0.747, 0.7615, 0.7615, 0.779,
0.802, 0.7615, 0.76, 0.7635, 0.7465, 0.757, 0.7725, 0.7605, 0.7765, 0.4965, 0.796, 0.7815, 0.814,
0.8085, 0.817, 0.805, 0.7995, 0.797, 0.4965, 0.8115, 0.4965, 0.8025, 0.814, 0.817, 0.8175], 
               "precision": [0.766633565, 0.7781065089, 0.7664092664, 0.7603960396, 0.7869822485,
0.7670565302, 0.7723735409, 0.7855044074, 0.777666999, 0.7729941292, 0.775, 0.7854984894,
0.7692307692, 0.7944389275, 0.789017341, 0.7917888563, 0.7585170341, 0.7286821705, 0.7415295257,
0.7341772152, 0.7519762846, 0.7470930233, 0.7722277722, 0.7987866532, 0.7504911591, 0.7502467917,
0.7524557957, 0.7298850575, 0.7448680352, 0.7602739726, 0.7524850895, 0.7662721893, 0, 0.8136125654,
0.785, 0.815920398, 0.8196721311, 0.8227593152, 0.8210197711, 0.8143153527, 0.7960591133, 0,
0.8315789474, 0, 0.8078470825, 0.8203834511, 0.8201798202, 0.8248987854]}
with open("unnormalizedmovies1.txt", "w") as o:
  o.write("Column B" + "\n")
  o.write("k = 2" + "\n")
  for category in scores2["b unnormalized"].keys():
    o.write(category + "\n")
    o.write("accuracy" + "\n")
    o.write(str(stats.spearmanr(scores2["b unnormalized"][category], performance["accuracy"]))
     + "\n")
    o.write("precision" + "\n")
    o.write(str(stats.spearmanr(scores2["b unnormalized"][category], performance["precision"])) 
    + "\n")
  o.write("k = 3" + "\n")
  for category in scores3["b unnormalized"].keys():
    o.write(category + "\n")
    o.write("accuracy" + "\n")
    o.write(str(stats.spearmanr(scores3["b unnormalized"][category], performance["accuracy"]))
     + "\n")
    o.write("precision" + "\n")
    o.write(str(stats.spearmanr(scores3["b unnormalized"][category], performance["precision"])) 
    + "\n")
  o.write("k = 4" + "\n")
  for category in scores4["b unnormalized"].keys():
    o.write(category + "\n")
    o.write("accuracy" + "\n")
    o.write(str(stats.spearmanr(scores4["b unnormalized"][category], performance["accuracy"]))
     + "\n")
    o.write("precision" + "\n")
    o.write(str(stats.spearmanr(scores4["b unnormalized"][category], performance["precision"])) 
    + "\n")
  # C
  o.write("Column C" + "\n")
  o.write("k = 2" + "\n")
  for category in scores2["c unnormalized"].keys():
    o.write(category + "\n")
    o.write("accuracy" + "\n")
    o.write(str(stats.spearmanr(scores2["c unnormalized"][category], performance["accuracy"]))
     + "\n")
    o.write("precision" + "\n")
    o.write(str(stats.spearmanr(scores2["c unnormalized"][category], performance["precision"])) 
    + "\n")
  o.write("k = 3" + "\n")
  for category in scores3["c unnormalized"].keys():
    o.write(category + "\n")
    o.write("accuracy" + "\n")
    o.write(str(stats.spearmanr(scores3["c unnormalized"][category], performance["accuracy"]))
     + "\n")
    o.write("precision" + "\n")
    o.write(str(stats.spearmanr(scores3["c unnormalized"][category], performance["precision"])) 
    + "\n")
  o.write("k = 4" + "\n")
  for category in scores4["c unnormalized"].keys():
    o.write(category + "\n")
    o.write("accuracy" + "\n")
    o.write(str(stats.spearmanr(scores4["c unnormalized"][category], performance["accuracy"]))
     + "\n")
    o.write("precision" + "\n")
    o.write(str(stats.spearmanr(scores4["c unnormalized"][category], performance["precision"])) 
    + "\n")
  # D
  o.write("Column D" + "\n")
  o.write("k = 2" + "\n")
  for category in scores2["d unnormalized"].keys():
    o.write(category + "\n")
    o.write("accuracy" + "\n")
    o.write(str(stats.spearmanr(scores2["d unnormalized"][category], performance["accuracy"]))
     + "\n")
    o.write("precision" + "\n")
    o.write(str(stats.spearmanr(scores2["d unnormalized"][category], performance["precision"])) 
    + "\n")
  o.write("k = 3" + "\n")
  for category in scores3["d unnormalized"].keys():
    o.write(category + "\n")
    o.write("accuracy" + "\n")
    o.write(str(stats.spearmanr(scores3["d unnormalized"][category], performance["accuracy"]))
     + "\n")
    o.write("precision" + "\n")
    o.write(str(stats.spearmanr(scores3["d unnormalized"][category], performance["precision"])) 
    + "\n")
  o.write("k = 4" + "\n")
  for category in scores4["d unnormalized"].keys():
    o.write(category + "\n")
    o.write("accuracy" + "\n")
    o.write(str(stats.spearmanr(scores4["d unnormalized"][category], performance["accuracy"]))
     + "\n")
    o.write("precision" + "\n")
    o.write(str(stats.spearmanr(scores4["d unnormalized"][category], performance["precision"])) 
    + "\n")


with open("normalizedmovies1.txt", "w") as o:
  o.write("Column B" + "\n")
  o.write("k = 2" + "\n")
  for category in scores2["b normalized"].keys():
    o.write(category + "\n")
    o.write("accuracy" + "\n")
    o.write(str(stats.spearmanr(scores2["b normalized"][category], performance["accuracy"]))
     + "\n")
    o.write("precision" + "\n")
    o.write(str(stats.spearmanr(scores2["b normalized"][category], performance["precision"])) 
    + "\n")
  o.write("k = 3" + "\n")
  for category in scores3["b normalized"].keys():
    o.write(category + "\n")
    o.write("accuracy" + "\n")
    o.write(str(stats.spearmanr(scores3["b normalized"][category], performance["accuracy"]))
     + "\n")
    o.write("precision" + "\n")
    o.write(str(stats.spearmanr(scores3["b normalized"][category], performance["precision"])) 
    + "\n")
  o.write("k = 4" + "\n")
  for category in scores4["b normalized"].keys():
    o.write(category + "\n")
    o.write("accuracy" + "\n")
    o.write(str(stats.spearmanr(scores4["b normalized"][category], performance["accuracy"]))
     + "\n")
    o.write("precision" + "\n")
    o.write(str(stats.spearmanr(scores4["b normalized"][category], performance["precision"])) 
    + "\n")
  # C
  o.write("Column C" + "\n")
  o.write("k = 2" + "\n")
  for category in scores2["c normalized"].keys():
    o.write(category + "\n")
    o.write("accuracy" + "\n")
    o.write(str(stats.spearmanr(scores2["c normalized"][category], performance["accuracy"]))
     + "\n")
    o.write("precision" + "\n")
    o.write(str(stats.spearmanr(scores2["c normalized"][category], performance["precision"])) 
    + "\n")
  o.write("k = 3" + "\n")
  for category in scores3["c normalized"].keys():
    o.write(category + "\n")
    o.write("accuracy" + "\n")
    o.write(str(stats.spearmanr(scores3["c normalized"][category], performance["accuracy"]))
     + "\n")
    o.write("precision" + "\n")
    o.write(str(stats.spearmanr(scores3["c normalized"][category], performance["precision"])) 
    + "\n")
  o.write("k = 4" + "\n")
  for category in scores4["c normalized"].keys():
    o.write(category + "\n")
    o.write("accuracy" + "\n")
    o.write(str(stats.spearmanr(scores4["c normalized"][category], performance["accuracy"]))
     + "\n")
    o.write("precision" + "\n")
    o.write(str(stats.spearmanr(scores4["c normalized"][category], performance["precision"])) 
    + "\n")
  # D
  o.write("Column D" + "\n")
  o.write("k = 2" + "\n")
  for category in scores2["d normalized"].keys():
    o.write(category + "\n")
    o.write("accuracy" + "\n")
    o.write(str(stats.spearmanr(scores2["d normalized"][category], performance["accuracy"]))
     + "\n")
    o.write("precision" + "\n")
    o.write(str(stats.spearmanr(scores2["d normalized"][category], performance["precision"])) 
    + "\n")
  o.write("k = 3" + "\n")
  for category in scores3["d normalized"].keys():
    o.write(category + "\n")
    o.write("accuracy" + "\n")
    o.write(str(stats.spearmanr(scores3["d normalized"][category], performance["accuracy"]))
     + "\n")
    o.write("precision" + "\n")
    o.write(str(stats.spearmanr(scores3["d normalized"][category], performance["precision"])) 
    + "\n")
  o.write("k = 4" + "\n")
  for category in scores4["d normalized"].keys():
    o.write(category + "\n")
    o.write("accuracy" + "\n")
    o.write(str(stats.spearmanr(scores4["d normalized"][category], performance["accuracy"]))
     + "\n")
    o.write("precision" + "\n")
    o.write(str(stats.spearmanr(scores4["d normalized"][category], performance["precision"])) 
    + "\n")

# %%
# movies, 30 trials
from scipy import stats
import csv
scores2 = {"b normalized": {}, "c normalized": {}, "d normalized": {},
          "b unnormalized": {}, "c unnormalized": {}, "d unnormalized": {}}
scores3 = {"b normalized": {}, "c normalized": {}, "d normalized": {},
          "b unnormalized": {}, "c unnormalized": {}, "d unnormalized": {}}
scores4 = {"b normalized": {}, "c normalized": {}, "d normalized": {},
          "b unnormalized": {}, "c unnormalized": {}, "d unnormalized": {}}
conversion = {"du": "d unnormalized", "dn": "d normalized",
              "cu": "c unnormalized", "cn": "c normalized",
              "bu": "b unnormalized", "bn": "b normalized"}
for k in conversion.keys():
  with open(k + "2.csv", newline="") as csvfile:
    reader = csv.reader(csvfile)
    rows = [row for row in reader]
    for i in range(len(rows[0][1:])):
      scores2[conversion[k]][rows[0][i + 1]] = [float(score[i + 1]) for score in rows[1:]]
for k in conversion.keys():
  with open(k + "3.csv", newline="") as csvfile:
    reader = csv.reader(csvfile)
    rows = [row for row in reader]
    for i in range(len(rows[0][1:])):
      scores3[conversion[k]][rows[0][i + 1]] = [float(score[i + 1]) for score in rows[1:]]
for k in conversion.keys():
  with open(k + "4.csv", newline="") as csvfile:
    reader = csv.reader(csvfile)
    rows = [row for row in reader]
    for i in range(len(rows[0][1:])):
      scores4[conversion[k]][rows[0][i + 1]] = [float(score[i + 1]) for score in rows[1:]]
performance = {"accuracy": [0.7612833333, 0.7718833333, 0.77695, 0.7657, 0.7893666667, 0.7819166667,
0.7795166667, 0.7907666667, 0.7713666667, 0.7710666667, 0.7894666667, 0.7805833333, 0.7759833333,
0.7974, 0.7942, 0.7969833333, 0.7597, 0.7448833333, 0.7526, 0.7496166667, 0.7551833333, 0.7608166667,
0.77185, 0.7956833333, 0.752, 0.7606166667, 0.7646333333, 0.7456333333, 0.7637, 0.7743166667,
0.7670833333, 0.77125, 0.7612833333, 0.7718833333, 0.77695, 0.7657, 0.7893666667, 0.7819166667,
0.7795166667, 0.7907666667, 0.7713666667, 0.7710666667, 0.7894666667, 0.7805833333, 0.7759833333,
0.7974, 0.7942, 0.7969833333], 
               "precision": [0.763348744, 0.7714896909, 0.7742086779, 0.7677412447, 0.7931870812,
0.7813069819, 0.7742128827, 0.7917228164, 0.7724251135, 0.772333931, 0.784581553, 0.7830277282,
0.7761954659, 0.7972427698, 0.7911590715, 0.79543841, 0.7691472101, 0.7488560705, 0.7545668759,
0.7551853148, 0.7603101619, 0.7650302036, 0.7749339314, 0.8093964338, 0.7578030234, 0.7643962351,
0.7663300735, 0.7492962514, 0.7663226472, 0.7789635676, 0.7738860885, 0.7732348065, 0.763348744,
0.7714896909, 0.7742086779, 0.7677412447, 0.7931870812, 0.7813069819, 0.7742128827, 0.7917228164,
0.7724251135, 0.772333931, 0.784581553, 0.7830277282, 0.7761954659, 0.7972427698, 0.7911590715,
0.79543841]}
with open("unnormalizedmovies30.txt", "w") as o:
  o.write("Column B" + "\n")
  o.write("k = 2" + "\n")
  for category in scores2["b unnormalized"].keys():
    o.write(category + "\n")
    o.write("accuracy" + "\n")
    o.write(str(stats.spearmanr(scores2["b unnormalized"][category], performance["accuracy"]))
     + "\n")
    o.write("precision" + "\n")
    o.write(str(stats.spearmanr(scores2["b unnormalized"][category], performance["precision"])) 
    + "\n")
  o.write("k = 3" + "\n")
  for category in scores3["b unnormalized"].keys():
    o.write(category + "\n")
    o.write("accuracy" + "\n")
    o.write(str(stats.spearmanr(scores3["b unnormalized"][category], performance["accuracy"]))
     + "\n")
    o.write("precision" + "\n")
    o.write(str(stats.spearmanr(scores3["b unnormalized"][category], performance["precision"])) 
    + "\n")
  o.write("k = 4" + "\n")
  for category in scores4["b unnormalized"].keys():
    o.write(category + "\n")
    o.write("accuracy" + "\n")
    o.write(str(stats.spearmanr(scores4["b unnormalized"][category], performance["accuracy"]))
     + "\n")
    o.write("precision" + "\n")
    o.write(str(stats.spearmanr(scores4["b unnormalized"][category], performance["precision"])) 
    + "\n")
  # C
  o.write("Column C" + "\n")
  o.write("k = 2" + "\n")
  for category in scores2["c unnormalized"].keys():
    o.write(category + "\n")
    o.write("accuracy" + "\n")
    o.write(str(stats.spearmanr(scores2["c unnormalized"][category], performance["accuracy"]))
     + "\n")
    o.write("precision" + "\n")
    o.write(str(stats.spearmanr(scores2["c unnormalized"][category], performance["precision"])) 
    + "\n")
  o.write("k = 3" + "\n")
  for category in scores3["c unnormalized"].keys():
    o.write(category + "\n")
    o.write("accuracy" + "\n")
    o.write(str(stats.spearmanr(scores3["c unnormalized"][category], performance["accuracy"]))
     + "\n")
    o.write("precision" + "\n")
    o.write(str(stats.spearmanr(scores3["c unnormalized"][category], performance["precision"])) 
    + "\n")
  o.write("k = 4" + "\n")
  for category in scores4["c unnormalized"].keys():
    o.write(category + "\n")
    o.write("accuracy" + "\n")
    o.write(str(stats.spearmanr(scores4["c unnormalized"][category], performance["accuracy"]))
     + "\n")
    o.write("precision" + "\n")
    o.write(str(stats.spearmanr(scores4["c unnormalized"][category], performance["precision"])) 
    + "\n")
  # D
  o.write("Column D" + "\n")
  o.write("k = 2" + "\n")
  for category in scores2["d unnormalized"].keys():
    o.write(category + "\n")
    o.write("accuracy" + "\n")
    o.write(str(stats.spearmanr(scores2["d unnormalized"][category], performance["accuracy"]))
     + "\n")
    o.write("precision" + "\n")
    o.write(str(stats.spearmanr(scores2["d unnormalized"][category], performance["precision"])) 
    + "\n")
  o.write("k = 3" + "\n")
  for category in scores3["d unnormalized"].keys():
    o.write(category + "\n")
    o.write("accuracy" + "\n")
    o.write(str(stats.spearmanr(scores3["d unnormalized"][category], performance["accuracy"]))
     + "\n")
    o.write("precision" + "\n")
    o.write(str(stats.spearmanr(scores3["d unnormalized"][category], performance["precision"])) 
    + "\n")
  o.write("k = 4" + "\n")
  for category in scores4["d unnormalized"].keys():
    o.write(category + "\n")
    o.write("accuracy" + "\n")
    o.write(str(stats.spearmanr(scores4["d unnormalized"][category], performance["accuracy"]))
     + "\n")
    o.write("precision" + "\n")
    o.write(str(stats.spearmanr(scores4["d unnormalized"][category], performance["precision"])) 
    + "\n")


with open("normalizedmovies30.txt", "w") as o:
  o.write("Column B" + "\n")
  o.write("k = 2" + "\n")
  for category in scores2["b normalized"].keys():
    o.write(category + "\n")
    o.write("accuracy" + "\n")
    o.write(str(stats.spearmanr(scores2["b normalized"][category], performance["accuracy"]))
     + "\n")
    o.write("precision" + "\n")
    o.write(str(stats.spearmanr(scores2["b normalized"][category], performance["precision"])) 
    + "\n")
  o.write("k = 3" + "\n")
  for category in scores3["b normalized"].keys():
    o.write(category + "\n")
    o.write("accuracy" + "\n")
    o.write(str(stats.spearmanr(scores3["b normalized"][category], performance["accuracy"]))
     + "\n")
    o.write("precision" + "\n")
    o.write(str(stats.spearmanr(scores3["b normalized"][category], performance["precision"])) 
    + "\n")
  o.write("k = 4" + "\n")
  for category in scores4["b normalized"].keys():
    o.write(category + "\n")
    o.write("accuracy" + "\n")
    o.write(str(stats.spearmanr(scores4["b normalized"][category], performance["accuracy"]))
     + "\n")
    o.write("precision" + "\n")
    o.write(str(stats.spearmanr(scores4["b normalized"][category], performance["precision"])) 
    + "\n")
  # C
  o.write("Column C" + "\n")
  o.write("k = 2" + "\n")
  for category in scores2["c normalized"].keys():
    o.write(category + "\n")
    o.write("accuracy" + "\n")
    o.write(str(stats.spearmanr(scores2["c normalized"][category], performance["accuracy"]))
     + "\n")
    o.write("precision" + "\n")
    o.write(str(stats.spearmanr(scores2["c normalized"][category], performance["precision"])) 
    + "\n")
  o.write("k = 3" + "\n")
  for category in scores3["c normalized"].keys():
    o.write(category + "\n")
    o.write("accuracy" + "\n")
    o.write(str(stats.spearmanr(scores3["c normalized"][category], performance["accuracy"]))
     + "\n")
    o.write("precision" + "\n")
    o.write(str(stats.spearmanr(scores3["c normalized"][category], performance["precision"])) 
    + "\n")
  o.write("k = 4" + "\n")
  for category in scores4["c normalized"].keys():
    o.write(category + "\n")
    o.write("accuracy" + "\n")
    o.write(str(stats.spearmanr(scores4["c normalized"][category], performance["accuracy"]))
     + "\n")
    o.write("precision" + "\n")
    o.write(str(stats.spearmanr(scores4["c normalized"][category], performance["precision"])) 
    + "\n")
  # D
  o.write("Column D" + "\n")
  o.write("k = 2" + "\n")
  for category in scores2["d normalized"].keys():
    o.write(category + "\n")
    o.write("accuracy" + "\n")
    o.write(str(stats.spearmanr(scores2["d normalized"][category], performance["accuracy"]))
     + "\n")
    o.write("precision" + "\n")
    o.write(str(stats.spearmanr(scores2["d normalized"][category], performance["precision"])) 
    + "\n")
  o.write("k = 3" + "\n")
  for category in scores3["d normalized"].keys():
    o.write(category + "\n")
    o.write("accuracy" + "\n")
    o.write(str(stats.spearmanr(scores3["d normalized"][category], performance["accuracy"]))
     + "\n")
    o.write("precision" + "\n")
    o.write(str(stats.spearmanr(scores3["d normalized"][category], performance["precision"])) 
    + "\n")
  o.write("k = 4" + "\n")
  for category in scores4["d normalized"].keys():
    o.write(category + "\n")
    o.write("accuracy" + "\n")
    o.write(str(stats.spearmanr(scores4["d normalized"][category], performance["accuracy"]))
     + "\n")
    o.write("precision" + "\n")
    o.write(str(stats.spearmanr(scores4["d normalized"][category], performance["precision"])) 
    + "\n")
